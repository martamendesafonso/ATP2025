# %%
import json
import FreeSimpleGUI as sg

import matplotlib
matplotlib.use("TkAgg")  # <- antes do pyplot

import matplotlib.pyplot as plt
import numpy as np

import clinic_extras as c  # <- o teu motor


CONFIG_PATH = "config.json"


# ---------------- CONFIG JSON ----------------
def load_config(path=CONFIG_PATH):
    defaults = {
        "NUM_MEDICOS": getattr(c, "NUM_MEDICOS", 3),
        "TAXA_CHEGADA_HORA": float(getattr(c, "TAXA_CHEGADA", 10 / 60.0)) * 60.0,  # doentes/hora
        "TEMPO_MEDIO_CONSULTA": getattr(c, "TEMPO_MEDIO_CONSULTA", 15),
        "TEMPO_SIMULACAO": getattr(c, "TEMPO_SIMULACAO", 480),
        "DISTRIBUICAO_TEMPO_CONSULTA": getattr(c, "DISTRIBUICAO_TEMPO_CONSULTA", "exponential"),
    }
    try:
        with open(path, encoding="utf-8") as f:
            cfg = json.load(f)

        # JSON guarda TAXA_CHEGADA em doentes/min (compatível com motor)
        if "TAXA_CHEGADA" in cfg and "TAXA_CHEGADA_HORA" not in cfg:
            cfg["TAXA_CHEGADA_HORA"] = float(cfg["TAXA_CHEGADA"]) * 60.0

        for k in defaults:
            if k in cfg:
                defaults[k] = cfg[k]
    except Exception:
        pass
    return defaults


def save_config(values, path=CONFIG_PATH):
    cfg = {
        "NUM_MEDICOS": int(values["NUM_MEDICOS"]),
        "TAXA_CHEGADA": float(values["TAXA_CHEGADA_HORA"]) / 60.0,  # doentes/min
        "TEMPO_MEDIO_CONSULTA": float(values["TEMPO_MEDIO_CONSULTA"]),
        "TEMPO_SIMULACAO": float(values["TEMPO_SIMULACAO"]),
        "DISTRIBUICAO_TEMPO_CONSULTA": values["DISTRIBUICAO_TEMPO_CONSULTA"],
    }
    with open(path, "w", encoding="utf-8") as f:
        json.dump(cfg, f, indent=2)


def apply_to_model(values):
    c.NUM_MEDICOS = int(values["NUM_MEDICOS"])
    c.TAXA_CHEGADA = float(values["TAXA_CHEGADA_HORA"]) / 60.0
    c.TEMPO_MEDIO_CONSULTA = float(values["TEMPO_MEDIO_CONSULTA"])
    c.TEMPO_SIMULACAO = float(values["TEMPO_SIMULACAO"])
    c.DISTRIBUICAO_TEMPO_CONSULTA = values["DISTRIBUICAO_TEMPO_CONSULTA"]


def parse_inputs(values):
    out = dict(values)
    out["NUM_MEDICOS"] = int(float(values["NUM_MEDICOS"]))
    out["TAXA_CHEGADA_HORA"] = float(values["TAXA_CHEGADA_HORA"])
    out["TEMPO_MEDIO_CONSULTA"] = float(values["TEMPO_MEDIO_CONSULTA"])
    out["TEMPO_SIMULACAO"] = float(values["TEMPO_SIMULACAO"])
    out["DISTRIBUICAO_TEMPO_CONSULTA"] = values["DISTRIBUICAO_TEMPO_CONSULTA"]
    return out


# ---------------- GRÁFICOS ----------------
def graf_esperas_por_atendimento(res):
    esperas = res["tempos_espera"]
    x = list(range(len(esperas)))

    plt.figure(figsize=(9, 4.5))
    plt.plot(x, esperas)
    plt.xlabel("Ordem dos atendimentos")
    plt.ylabel("Tempo de espera (min)")
    plt.title("Evolução do tempo de espera (por doente atendido)")
    plt.grid(True)
    plt.show()


def graf_lambda_vs_espera(repeticoes=20):
    resultados = []
    taxa_original = c.TAXA_CHEGADA

    for lam in range(10, 31):
        c.TAXA_CHEGADA = lam / 60.0

        esperas = []
        for _ in range(repeticoes):
            res = c.simula()
            esperas.append(res["tempo_medio_espera"])

        resultados.append((lam, float(np.mean(esperas))))

    c.TAXA_CHEGADA = taxa_original

    x = [lam for lam, _ in resultados]
    y = [v for _, v in resultados]

    plt.figure(figsize=(9, 4.5))
    plt.plot(x, y, label="Tempo médio de espera")
    plt.title("Relação entre λ e o tempo médio de espera")
    plt.xlabel("Taxa de chegada λ (doentes/hora)")
    plt.ylabel("Tempo médio de espera (min)")
    plt.grid(True)
    plt.legend()
    plt.show()


def graf_evolucao_fila(res):
    serie = res.get("serie_fila", [])
    tempos_h = [t / 60.0 for t, _ in serie]
    filas = [f for _, f in serie]

    plt.figure(figsize=(9, 4.5))
    plt.plot(tempos_h, filas)
    plt.xlabel("Tempo da simulação (horas)")
    plt.ylabel("Tamanho da fila")
    plt.title("Evolução do tamanho da fila ao longo do tempo")
    plt.grid(True)
    plt.show()


def graf_evolucao_ocup(res):
    serie = res.get("serie_ocup", [])

    # manter último valor por tempo
    ultimo = {}
    for t, occ in serie:
        ultimo[t] = occ

    tempos = sorted(ultimo.keys())
    tempos_h = [t / 60.0 for t in tempos]
    ocup_pct = [ultimo[t] * 100 for t in tempos]

    plt.figure(figsize=(9, 4.5))
    plt.plot(tempos_h, ocup_pct)
    plt.xlabel("Tempo (horas)")
    plt.ylabel("Ocupação média (%)")
    plt.title("Ocupação média dos médicos ao longo do tempo")
    plt.ylim(0, 105)
    plt.grid(True)
    plt.show()


def graf_hist_espera(res):
    esperas = res.get("tempos_espera", [])

    plt.figure(figsize=(9, 4.5))
    plt.hist(esperas, bins=20)
    plt.xlabel("Tempo de espera (min)")
    plt.ylabel("Número de doentes")
    plt.title("Distribuição dos tempos de espera")
    plt.grid(True)
    plt.show()


# ---------------- GUI ----------------
def main():
    sg.theme("SystemDefault")

    cfg = load_config(CONFIG_PATH)
    dist_opts = ["exponential", "normal", "uniform"]

    layout = [
        [sg.Text("App Simulação Clínica", font=("Arial", 16, "bold"))],

        [sg.Frame("Config (config.json)", [
            [sg.Text("Médicos", size=(12, 1)),
             sg.Input(str(cfg["NUM_MEDICOS"]), key="NUM_MEDICOS", size=(10, 1)),
             sg.Text("λ (doentes/h)", size=(12, 1)),
             sg.Input(str(cfg["TAXA_CHEGADA_HORA"]), key="TAXA_CHEGADA_HORA", size=(10, 1))],

            [sg.Text("T. médio consulta (min)", size=(18, 1)),
             sg.Input(str(cfg["TEMPO_MEDIO_CONSULTA"]), key="TEMPO_MEDIO_CONSULTA", size=(10, 1)),
             sg.Text("T. simulação (min)", size=(16, 1)),
             sg.Input(str(cfg["TEMPO_SIMULACAO"]), key="TEMPO_SIMULACAO", size=(10, 1))],

            [sg.Text("Distribuição", size=(12, 1)),
             sg.Combo(dist_opts, default_value=cfg["DISTRIBUICAO_TEMPO_CONSULTA"],
                      key="DISTRIBUICAO_TEMPO_CONSULTA", readonly=True),
             sg.Button("Guardar JSON", key="-SAVEJSON-"),
             sg.Button("Recarregar JSON", key="-LOADJSON-")]
        ])],

        [sg.Frame("Ações", [
            [sg.Button("Correr simulação", key="-RUN-", size=(18, 1)),
             sg.Button("Gráfico: esperas", key="-PLOT_ESP-", size=(16, 1), disabled=True),
             sg.Button("Gráfico: λ vs espera", key="-PLOT_LAM-", size=(16, 1)),
             sg.Button("Evolução fila", key="-PLOT_FILA-", size=(14, 1), disabled=True),
             sg.Button("Evolução ocupação", key="-PLOT_OCUP-", size=(16, 1), disabled=True),
             sg.Button("Histograma", key="-PLOT_HIST-", size=(12, 1), disabled=True),
             sg.Button("Sair", key="-EXIT-", size=(10, 1))]
        ])],

        [sg.Frame("λ vs espera", [
            [sg.Text("Repetições por λ:", size=(16, 1)),
             sg.Input("20", key="-REP-", size=(10, 1))]
        ])],

        [sg.Frame("Resultados (última simulação)", [
            [sg.Text("Doentes atendidos:", size=(26, 1)), sg.Text("-", key="-DOENTES-")],
            [sg.Text("Tempo médio de espera (min):", size=(26, 1)), sg.Text("-", key="-ESPERA-")],
            [sg.Text("Tempo médio de consulta (min):", size=(26, 1)), sg.Text("-", key="-CONSULTA-")],
            [sg.Text("Tempo médio no sistema (min):", size=(26, 1)), sg.Text("-", key="-SISTEMA-")],
            [sg.Text("Tamanho médio da fila:", size=(26, 1)), sg.Text("-", key="-FILA_MEDIA-")],
            [sg.Text("Tamanho máximo da fila:", size=(26, 1)), sg.Text("-", key="-FILA_MAX-")],
            [sg.Text("Ocupação média:", size=(26, 1)), sg.Text("-", key="-OCUP_MEDIA-")],
        ])],

        [sg.Frame("Ocupação por médico (%)", [
            [sg.Multiline("", key="-OCUP_MED-", size=(70, 8), disabled=True)]
        ])],

        [sg.Frame("Métricas por médico (extra)", [
            [sg.Multiline("", key="-MET_MED-", size=(70, 8), disabled=True)]
        ])],

        [sg.StatusBar("Pronto.", key="-STATUS-")]
    ]

    window = sg.Window(
        "Simulação Clínica",
        layout,
        finalize=True,
        size=(1100, 750),
        resizable=True
    )

    resultados = None

    while True:
        event, values = window.read()
        if event in (sg.WINDOW_CLOSED, "-EXIT-"):
            break

        if event == "-SAVEJSON-":
            try:
                v = parse_inputs(values)
                save_config(v, CONFIG_PATH)
                window["-STATUS-"].update("Config guardada em config.json")
            except Exception as e:
                sg.popup_error(f"Erro ao guardar JSON: {e}")

        if event == "-LOADJSON-":
            cfg = load_config(CONFIG_PATH)
            window["NUM_MEDICOS"].update(str(cfg["NUM_MEDICOS"]))
            window["TAXA_CHEGADA_HORA"].update(str(cfg["TAXA_CHEGADA_HORA"]))
            window["TEMPO_MEDIO_CONSULTA"].update(str(cfg["TEMPO_MEDIO_CONSULTA"]))
            window["TEMPO_SIMULACAO"].update(str(cfg["TEMPO_SIMULACAO"]))
            window["DISTRIBUICAO_TEMPO_CONSULTA"].update(cfg["DISTRIBUICAO_TEMPO_CONSULTA"])
            window["-STATUS-"].update("Config recarregada do JSON")

        if event == "-RUN-":
            window["-STATUS-"].update("A correr simulação...")
            try:
                v = parse_inputs(values)
                apply_to_model(v)

                resultados = c.simula()

                window["-DOENTES-"].update(str(resultados["doentes_atendidos"]))
                window["-ESPERA-"].update(f'{resultados["tempo_medio_espera"]:.2f}')
                window["-CONSULTA-"].update(f'{resultados["tempo_medio_consulta"]:.2f}')
                window["-SISTEMA-"].update(f'{resultados["tempo_medio_sistema"]:.2f}')
                window["-FILA_MEDIA-"].update(f'{resultados["tamanho_medio_fila"]:.2f}')
                window["-FILA_MAX-"].update(str(resultados["tamanho_max_fila"]))
                window["-OCUP_MEDIA-"].update(f'{resultados["ocupacao_media"]:.3f}')

                linhas = [f"{mid}: {v*100:.2f}%" for mid, v in resultados["ocupacao_por_medico"].items()]
                window["-OCUP_MED-"].update("\n".join(linhas))

                met = resultados.get("metricas_por_medico", {})
                if met:
                    linhas2 = []
                    for mid, mm in met.items():
                        linhas2.append(
                            f"{mid}: consultas={mm.get('consultas','-')} | "
                            f"ocup={mm.get('ocupacao',0)*100:.2f}% | "
                            f"tm_consulta={mm.get('tempo_medio_consulta',0):.2f} | "
                            f"t_ocup={mm.get('tempo_total_ocupado',0):.2f}"
                        )
                    window["-MET_MED-"].update("\n".join(linhas2))
                else:
                    window["-MET_MED-"].update("(o teu motor não devolveu metricas_por_medico)")

                window["-PLOT_ESP-"].update(disabled=False)
                window["-PLOT_FILA-"].update(disabled=False)
                window["-PLOT_OCUP-"].update(disabled=False)
                window["-PLOT_HIST-"].update(disabled=False)

                window["-STATUS-"].update("Simulação concluída.")
            except FileNotFoundError:
                window["-STATUS-"].update("Erro: pessoas.json não encontrado.")
                sg.popup_error("Não encontrei pessoas.json.\nConfirma que está na mesma pasta.")
            except Exception as e:
                window["-STATUS-"].update("Erro ao correr a simulação.")
                sg.popup_error(f"Erro: {e}")

        if event == "-PLOT_ESP-" and resultados is not None:
            graf_esperas_por_atendimento(resultados)

        if event == "-PLOT_FILA-" and resultados is not None:
            graf_evolucao_fila(resultados)

        if event == "-PLOT_OCUP-" and resultados is not None:
            graf_evolucao_ocup(resultados)

        if event == "-PLOT_HIST-" and resultados is not None:
            graf_hist_espera(resultados)

        if event == "-PLOT_LAM-":
            try:
                rep = int(values["-REP-"])
                if rep <= 0:
                    raise ValueError
            except Exception:
                sg.popup_error("Repetições inválidas. Mete um inteiro > 0.")
                continue

            window["-STATUS-"].update(f"A gerar gráfico λ vs espera (repetições={rep})...")
            try:
                # respeitar parâmetros atuais antes de variar λ
                v = parse_inputs(values)
                apply_to_model(v)

                graf_lambda_vs_espera(repeticoes=rep)
                window["-STATUS-"].update("Gráfico gerado.")
            except Exception as e:
                window["-STATUS-"].update("Erro ao gerar gráfico.")
                sg.popup_error(f"Erro: {e}")

    window.close()


if __name__ == "__main__":
    main()
# Out:
# Doentes atendidos: 91
# Tempo médio de espera (min): 10.93
# Tempo médio de consulta (min): 15.16
# Tempo médio no sistema (min): 26.09
# Tamanho médio da fila: 1.79 | Máx: 10
# Ocupação média: 0.853
# Ocupação por médico (%):
#   m0: 90.54%
#   m1: 77.78%
#   m2: 79.51%
# Métricas por médico:
#   m0: consultas=34 | ocup=90.54% | tm_consulta=14.82 min | t_ocup=504.04 min
#   m1: consultas=34 | ocup=77.78% | tm_consulta=12.73 min | t_ocup=432.96 min
#   m2: consultas=23 | ocup=79.51% | tm_consulta=19.24 min | t_ocup=442.60 min
# Doentes atendidos: 78
# Tempo médio de espera (min): 16.0
# Tempo médio de consulta (min): 16.39
# Tempo médio no sistema (min): 32.38
# Tamanho médio da fila: 2.42 | Máx: 11
# Ocupação média: 0.857
# Ocupação por médico (%):
#   m0: 83.18%
#   m1: 75.73%
#   m2: 79.55%
# Métricas por médico:
#   m0: consultas=24 | ocup=83.18% | tm_consulta=18.58 min | t_ocup=445.82 min
#   m1: consultas=29 | ocup=75.73% | tm_consulta=14.00 min | t_ocup=405.88 min
#   m2: consultas=25 | ocup=79.55% | tm_consulta=17.05 min | t_ocup=426.33 min
# Doentes atendidos: 87
# Tempo médio de espera (min): 6.92
# Tempo médio de consulta (min): 15.39
# Tempo médio no sistema (min): 22.31
# Tamanho médio da fila: 1.47 | Máx: 7
# Ocupação média: 0.891
# Ocupação por médico (%):
#   m0: 86.77%
#   m1: 81.44%
#   m2: 82.96%
# Métricas por médico:
#   m0: consultas=23 | ocup=86.77% | tm_consulta=20.11 min | t_ocup=462.53 min
#   m1: consultas=28 | ocup=81.44% | tm_consulta=15.50 min | t_ocup=434.09 min
#   m2: consultas=36 | ocup=82.96% | tm_consulta=12.28 min | t_ocup=442.19 min
# Doentes atendidos: 75
# Tempo médio de espera (min): 8.1
# Tempo médio de consulta (min): 14.32
# Tempo médio no sistema (min): 22.43
# Tamanho médio da fila: 1.3 | Máx: 10
# Ocupação média: 0.818
# Ocupação por médico (%):
#   m0: 79.64%
#   m1: 73.27%
#   m2: 59.19%
# Métricas por médico:
#   m0: consultas=24 | ocup=79.64% | tm_consulta=16.81 min | t_ocup=403.41 min
#   m1: consultas=29 | ocup=73.27% | tm_consulta=12.80 min | t_ocup=371.14 min
#   m2: consultas=22 | ocup=59.19% | tm_consulta=13.63 min | t_ocup=299.79 min
# Doentes atendidos: 78
# Tempo médio de espera (min): 3.77
# Tempo médio de consulta (min): 14.07
# Tempo médio no sistema (min): 17.84
# Tamanho médio da fila: 0.66 | Máx: 4
# Ocupação média: 0.776
# Ocupação por médico (%):
#   m0: 85.84%
#   m1: 72.33%
#   m2: 61.18%
# Métricas por médico:
#   m0: consultas=35 | ocup=85.84% | tm_consulta=12.27 min | t_ocup=429.38 min
#   m1: consultas=19 | ocup=72.33% | tm_consulta=19.04 min | t_ocup=361.79 min
#   m2: consultas=24 | ocup=61.18% | tm_consulta=12.75 min | t_ocup=306.02 min
# Doentes atendidos: 88
# Tempo médio de espera (min): 36.67
# Tempo médio de consulta (min): 18.02
# Tempo médio no sistema (min): 54.68
# Tamanho médio da fila: 5.59 | Máx: 17
# Ocupação média: 0.947
# Ocupação por médico (%):
#   m0: 98.96%
#   m1: 89.1%
#   m2: 89.11%
# Métricas por médico:
#   m0: consultas=26 | ocup=98.96% | tm_consulta=21.77 min | t_ocup=566.11 min
#   m1: consultas=32 | ocup=89.10% | tm_consulta=15.93 min | t_ocup=509.72 min
#   m2: consultas=30 | ocup=89.11% | tm_consulta=16.99 min | t_ocup=509.77 min
# Doentes atendidos: 79
# Tempo médio de espera (min): 25.34
# Tempo médio de consulta (min): 16.88
# Tempo médio no sistema (min): 42.22
# Tamanho médio da fila: 3.84 | Máx: 16
# Ocupação média: 0.865
# Ocupação por médico (%):
#   m0: 85.64%
#   m1: 81.5%
#   m2: 74.17%
# Métricas por médico:
#   m0: consultas=32 | ocup=85.64% | tm_consulta=14.79 min | t_ocup=473.22 min
#   m1: consultas=24 | ocup=81.50% | tm_consulta=18.76 min | t_ocup=450.35 min
#   m2: consultas=23 | ocup=74.17% | tm_consulta=17.82 min | t_ocup=409.86 min
# Doentes atendidos: 75
# Tempo médio de espera (min): 28.77
# Tempo médio de consulta (min): 15.89
# Tempo médio no sistema (min): 44.67
# Tamanho médio da fila: 4.85 | Máx: 14
# Ocupação média: 0.836
# Ocupação por médico (%):
#   m0: 82.04%
#   m1: 75.44%
#   m2: 70.5%
# Métricas por médico:
#   m0: consultas=32 | ocup=82.04% | tm_consulta=13.41 min | t_ocup=428.99 min
#   m1: consultas=23 | ocup=75.44% | tm_consulta=17.15 min | t_ocup=394.45 min
#   m2: consultas=20 | ocup=70.50% | tm_consulta=18.43 min | t_ocup=368.63 min
# Doentes atendidos: 82
# Tempo médio de espera (min): 14.58
# Tempo médio de consulta (min): 16.4
# Tempo médio no sistema (min): 30.98
# Tamanho médio da fila: 2.15 | Máx: 7
# Ocupação média: 0.89
# Ocupação por médico (%):
#   m0: 80.88%
#   m1: 83.96%
#   m2: 81.46%
# Métricas por médico:
#   m0: consultas=26 | ocup=80.88% | tm_consulta=16.99 min | t_ocup=441.72 min
#   m1: consultas=32 | ocup=83.96% | tm_consulta=14.33 min | t_ocup=458.52 min
#   m2: consultas=24 | ocup=81.46% | tm_consulta=18.54 min | t_ocup=444.89 min
# Doentes atendidos: 75
# Tempo médio de espera (min): 2.88
# Tempo médio de consulta (min): 11.48
# Tempo médio no sistema (min): 14.36
# Tamanho médio da fila: 0.51 | Máx: 5
# Ocupação média: 0.691
# Ocupação por médico (%):
#   m0: 68.74%
#   m1: 53.48%
#   m2: 51.14%
# Métricas por médico:
#   m0: consultas=29 | ocup=68.74% | tm_consulta=11.77 min | t_ocup=341.41 min
#   m1: consultas=24 | ocup=53.48% | tm_consulta=11.07 min | t_ocup=265.61 min
#   m2: consultas=22 | ocup=51.14% | tm_consulta=11.54 min | t_ocup=253.98 min
# Doentes atendidos: 83
# Tempo médio de espera (min): 25.71
# Tempo médio de consulta (min): 16.23
# Tempo médio no sistema (min): 41.95
# Tamanho médio da fila: 4.32 | Máx: 12
# Ocupação média: 0.888
# Ocupação por médico (%):
#   m0: 87.84%
#   m1: 87.31%
#   m2: 78.03%
# Métricas por médico:
#   m0: consultas=31 | ocup=87.84% | tm_consulta=15.08 min | t_ocup=467.43 min
#   m1: consultas=23 | ocup=87.31% | tm_consulta=20.20 min | t_ocup=464.60 min
#   m2: consultas=29 | ocup=78.03% | tm_consulta=14.32 min | t_ocup=415.20 min
# Doentes atendidos: 72
# Tempo médio de espera (min): 12.01
# Tempo médio de consulta (min): 15.34
# Tempo médio no sistema (min): 27.35
# Tamanho médio da fila: 1.92 | Máx: 10
# Ocupação média: 0.812
# Ocupação por médico (%):
#   m0: 70.6%
#   m1: 72.55%
#   m2: 59.03%
# Métricas por médico:
#   m0: consultas=27 | ocup=70.60% | tm_consulta=14.28 min | t_ocup=385.65 min
#   m1: consultas=22 | ocup=72.55% | tm_consulta=18.01 min | t_ocup=396.29 min
#   m2: consultas=23 | ocup=59.03% | tm_consulta=14.02 min | t_ocup=322.43 min
# Doentes atendidos: 79
# Tempo médio de espera (min): 8.45
# Tempo médio de consulta (min): 17.07
# Tempo médio no sistema (min): 25.51
# Tamanho médio da fila: 1.3 | Máx: 6
# Ocupação média: 0.892
# Ocupação por médico (%):
#   m0: 89.58%
#   m1: 87.31%
#   m2: 85.65%
# Métricas por médico:
#   m0: consultas=26 | ocup=89.58% | tm_consulta=17.69 min | t_ocup=460.02 min
#   m1: consultas=30 | ocup=87.31% | tm_consulta=14.95 min | t_ocup=448.37 min
#   m2: consultas=23 | ocup=85.65% | tm_consulta=19.12 min | t_ocup=439.83 min
# Doentes atendidos: 81
# Tempo médio de espera (min): 22.22
# Tempo médio de consulta (min): 15.1
# Tempo médio no sistema (min): 37.32
# Tamanho médio da fila: 4.25 | Máx: 13
# Ocupação média: 0.846
# Ocupação por médico (%):
#   m0: 82.0%
#   m1: 81.19%
#   m2: 68.76%
# Métricas por médico:
#   m0: consultas=32 | ocup=82.00% | tm_consulta=13.51 min | t_ocup=432.29 min
#   m1: consultas=26 | ocup=81.19% | tm_consulta=16.46 min | t_ocup=428.01 min
#   m2: consultas=23 | ocup=68.76% | tm_consulta=15.76 min | t_ocup=362.48 min
# Doentes atendidos: 74
# Tempo médio de espera (min): 9.92
# Tempo médio de consulta (min): 17.19
# Tempo médio no sistema (min): 27.11
# Tamanho médio da fila: 1.7 | Máx: 8
# Ocupação média: 0.894
# Ocupação por médico (%):
#   m0: 91.01%
#   m1: 79.13%
#   m2: 85.54%
# Métricas por médico:
#   m0: consultas=22 | ocup=91.01% | tm_consulta=20.58 min | t_ocup=452.69 min
#   m1: consultas=29 | ocup=79.13% | tm_consulta=13.57 min | t_ocup=393.59 min
#   m2: consultas=23 | ocup=85.54% | tm_consulta=18.50 min | t_ocup=425.48 min
# Doentes atendidos: 82
# Tempo médio de espera (min): 21.09
# Tempo médio de consulta (min): 14.92
# Tempo médio no sistema (min): 36.01
# Tamanho médio da fila: 3.9 | Máx: 14
# Ocupação média: 0.827
# Ocupação por médico (%):
#   m0: 85.23%
#   m1: 81.77%
#   m2: 74.87%
# Métricas por médico:
#   m0: consultas=30 | ocup=85.23% | tm_consulta=14.37 min | t_ocup=430.98 min
#   m1: consultas=26 | ocup=81.77% | tm_consulta=15.90 min | t_ocup=413.50 min
#   m2: consultas=26 | ocup=74.87% | tm_consulta=14.56 min | t_ocup=378.62 min
# Doentes atendidos: 75
# Tempo médio de espera (min): 6.28
# Tempo médio de consulta (min): 15.35
# Tempo médio no sistema (min): 21.63
# Tamanho médio da fila: 1.03 | Máx: 6
# Ocupação média: 0.82
# Ocupação por médico (%):
#   m0: 79.53%
#   m1: 76.21%
#   m2: 79.22%
# Métricas por médico:
#   m0: consultas=34 | ocup=79.53% | tm_consulta=11.46 min | t_ocup=389.67 min
#   m1: consultas=20 | ocup=76.21% | tm_consulta=18.67 min | t_ocup=373.44 min
#   m2: consultas=21 | ocup=79.22% | tm_consulta=18.48 min | t_ocup=388.16 min
# Doentes atendidos: 74
# Tempo médio de espera (min): 2.12
# Tempo médio de consulta (min): 12.0
# Tempo médio no sistema (min): 14.12
# Tamanho médio da fila: 0.55 | Máx: 5
# Ocupação média: 0.676
# Ocupação por médico (%):
#   m0: 79.28%
#   m1: 62.65%
#   m2: 43.18%
# Métricas por médico:
#   m0: consultas=28 | ocup=79.28% | tm_consulta=13.58 min | t_ocup=380.20 min
#   m1: consultas=27 | ocup=62.65% | tm_consulta=11.13 min | t_ocup=300.45 min
#   m2: consultas=19 | ocup=43.18% | tm_consulta=10.90 min | t_ocup=207.07 min
# Doentes atendidos: 93
# Tempo médio de espera (min): 29.17
# Tempo médio de consulta (min): 15.54
# Tempo médio no sistema (min): 44.71
# Tamanho médio da fila: 5.48 | Máx: 12
# Ocupação média: 0.961
# Ocupação por médico (%):
#   m0: 98.21%
#   m1: 96.44%
#   m2: 91.29%
# Métricas por médico:
#   m0: consultas=32 | ocup=98.21% | tm_consulta=15.51 min | t_ocup=496.34 min
#   m1: consultas=27 | ocup=96.44% | tm_consulta=18.05 min | t_ocup=487.38 min
#   m2: consultas=34 | ocup=91.29% | tm_consulta=13.57 min | t_ocup=461.37 min
# Doentes atendidos: 68
# Tempo médio de espera (min): 4.49
# Tempo médio de consulta (min): 13.87
# Tempo médio no sistema (min): 18.36
# Tamanho médio da fila: 0.85 | Máx: 6
# Ocupação média: 0.76
# Ocupação por médico (%):
#   m0: 75.07%
#   m1: 56.18%
#   m2: 52.68%
# Métricas por médico:
#   m0: consultas=27 | ocup=75.07% | tm_consulta=14.26 min | t_ocup=384.89 min
#   m1: consultas=20 | ocup=56.18% | tm_consulta=14.40 min | t_ocup=288.08 min
#   m2: consultas=21 | ocup=52.68% | tm_consulta=12.86 min | t_ocup=270.11 min
# Doentes atendidos: 85
# Tempo médio de espera (min): 15.91
# Tempo médio de consulta (min): 18.29
# Tempo médio no sistema (min): 34.2
# Tamanho médio da fila: 2.47 | Máx: 11
# Ocupação média: 0.935
# Ocupação por médico (%):
#   m0: 94.35%
#   m1: 89.03%
#   m2: 88.7%
# Métricas por médico:
#   m0: consultas=27 | ocup=94.35% | tm_consulta=19.97 min | t_ocup=539.15 min
#   m1: consultas=33 | ocup=89.03% | tm_consulta=15.42 min | t_ocup=508.74 min
#   m2: consultas=25 | ocup=88.70% | tm_consulta=20.27 min | t_ocup=506.86 min
# Doentes atendidos: 81
# Tempo médio de espera (min): 7.22
# Tempo médio de consulta (min): 14.75
# Tempo médio no sistema (min): 21.97
# Tamanho médio da fila: 1.49 | Máx: 7
# Ocupação média: 0.852
# Ocupação por médico (%):
#   m0: 85.77%
#   m1: 79.56%
#   m2: 71.36%
# Métricas por médico:
#   m0: consultas=27 | ocup=85.77% | tm_consulta=16.04 min | t_ocup=432.96 min
#   m1: consultas=27 | ocup=79.56% | tm_consulta=14.87 min | t_ocup=401.62 min
#   m2: consultas=27 | ocup=71.36% | tm_consulta=13.34 min | t_ocup=360.22 min
# Doentes atendidos: 69
# Tempo médio de espera (min): 6.94
# Tempo médio de consulta (min): 14.71
# Tempo médio no sistema (min): 21.65
# Tamanho médio da fila: 1.09 | Máx: 7
# Ocupação média: 0.761
# Ocupação por médico (%):
#   m0: 79.03%
#   m1: 66.73%
#   m2: 61.1%
# Métricas por médico:
#   m0: consultas=26 | ocup=79.03% | tm_consulta=14.91 min | t_ocup=387.74 min
#   m1: consultas=24 | ocup=66.73% | tm_consulta=13.64 min | t_ocup=327.36 min
#   m2: consultas=19 | ocup=61.10% | tm_consulta=15.78 min | t_ocup=299.77 min
# Doentes atendidos: 84
# Tempo médio de espera (min): 10.82
# Tempo médio de consulta (min): 13.96
# Tempo médio no sistema (min): 24.78
# Tamanho médio da fila: 1.89 | Máx: 7
# Ocupação média: 0.871
# Ocupação por médico (%):
#   m0: 84.37%
#   m1: 79.0%
#   m2: 79.4%
# Métricas por médico:
#   m0: consultas=32 | ocup=84.37% | tm_consulta=12.73 min | t_ocup=407.49 min
#   m1: consultas=22 | ocup=79.00% | tm_consulta=17.34 min | t_ocup=381.58 min
#   m2: consultas=30 | ocup=79.40% | tm_consulta=12.78 min | t_ocup=383.50 min
# Doentes atendidos: 78
# Tempo médio de espera (min): 17.83
# Tempo médio de consulta (min): 16.3
# Tempo médio no sistema (min): 34.13
# Tamanho médio da fila: 3.24 | Máx: 13
# Ocupação média: 0.88
# Ocupação por médico (%):
#   m0: 86.54%
#   m1: 77.36%
#   m2: 82.98%
# Métricas por médico:
#   m0: consultas=30 | ocup=86.54% | tm_consulta=14.86 min | t_ocup=445.76 min
#   m1: consultas=19 | ocup=77.36% | tm_consulta=20.97 min | t_ocup=398.50 min
#   m2: consultas=29 | ocup=82.98% | tm_consulta=14.74 min | t_ocup=427.43 min
# Doentes atendidos: 98
# Tempo médio de espera (min): 37.5
# Tempo médio de consulta (min): 16.64
# Tempo médio no sistema (min): 54.13
# Tamanho médio da fila: 6.22 | Máx: 18
# Ocupação média: 0.961
# Ocupação por médico (%):
#   m0: 95.76%
#   m1: 92.49%
#   m2: 94.7%
# Métricas por médico:
#   m0: consultas=33 | ocup=95.76% | tm_consulta=16.72 min | t_ocup=551.85 min
#   m1: consultas=36 | ocup=92.49% | tm_consulta=14.81 min | t_ocup=533.03 min
#   m2: consultas=29 | ocup=94.70% | tm_consulta=18.82 min | t_ocup=545.73 min
# Doentes atendidos: 99
# Tempo médio de espera (min): 18.72
# Tempo médio de consulta (min): 14.05
# Tempo médio no sistema (min): 32.78
# Tamanho médio da fila: 3.98 | Máx: 13
# Ocupação média: 0.931
# Ocupação por médico (%):
#   m0: 95.96%
#   m1: 90.99%
#   m2: 88.86%
# Métricas por médico:
#   m0: consultas=38 | ocup=95.96% | tm_consulta=12.74 min | t_ocup=484.03 min
#   m1: consultas=29 | ocup=90.99% | tm_consulta=15.83 min | t_ocup=458.95 min
#   m2: consultas=32 | ocup=88.86% | tm_consulta=14.01 min | t_ocup=448.21 min
# Doentes atendidos: 91
# Tempo médio de espera (min): 13.56
# Tempo médio de consulta (min): 14.75
# Tempo médio no sistema (min): 28.32
# Tamanho médio da fila: 2.46 | Máx: 11
# Ocupação média: 0.89
# Ocupação por médico (%):
#   m0: 87.33%
#   m1: 82.37%
#   m2: 90.8%
# Métricas por médico:
#   m0: consultas=37 | ocup=87.33% | tm_consulta=12.16 min | t_ocup=450.10 min
#   m1: consultas=34 | ocup=82.37% | tm_consulta=12.49 min | t_ocup=424.55 min
#   m2: consultas=20 | ocup=90.80% | tm_consulta=23.40 min | t_ocup=468.03 min
# Doentes atendidos: 88
# Tempo médio de espera (min): 25.62
# Tempo médio de consulta (min): 16.78
# Tempo médio no sistema (min): 42.39
# Tamanho médio da fila: 4.78 | Máx: 15
# Ocupação média: 0.945
# Ocupação por médico (%):
#   m0: 85.96%
#   m1: 92.5%
#   m2: 85.83%
# Métricas por médico:
#   m0: consultas=35 | ocup=85.96% | tm_consulta=13.72 min | t_ocup=480.12 min
#   m1: consultas=24 | ocup=92.50% | tm_consulta=21.53 min | t_ocup=516.69 min
#   m2: consultas=29 | ocup=85.83% | tm_consulta=16.53 min | t_ocup=479.44 min
# Doentes atendidos: 81
# Tempo médio de espera (min): 8.78
# Tempo médio de consulta (min): 16.35
# Tempo médio no sistema (min): 25.13
# Tamanho médio da fila: 1.72 | Máx: 8
# Ocupação média: 0.909
# Ocupação por médico (%):
#   m0: 87.33%
#   m1: 82.34%
#   m2: 88.48%
# Métricas por médico:
#   m0: consultas=28 | ocup=87.33% | tm_consulta=16.00 min | t_ocup=448.03 min
#   m1: consultas=27 | ocup=82.34% | tm_consulta=15.64 min | t_ocup=422.40 min
#   m2: consultas=26 | ocup=88.48% | tm_consulta=17.46 min | t_ocup=453.89 min
# Doentes atendidos: 103
# Tempo médio de espera (min): 28.41
# Tempo médio de consulta (min): 16.81
# Tempo médio no sistema (min): 45.21
# Tamanho médio da fila: 4.91 | Máx: 13
# Ocupação média: 0.981
# Ocupação por médico (%):
#   m0: 96.24%
#   m1: 96.73%
#   m2: 99.34%
# Métricas por médico:
#   m0: consultas=34 | ocup=96.24% | tm_consulta=16.76 min | t_ocup=569.94 min
#   m1: consultas=37 | ocup=96.73% | tm_consulta=15.48 min | t_ocup=572.84 min
#   m2: consultas=32 | ocup=99.34% | tm_consulta=18.38 min | t_ocup=588.26 min
# Doentes atendidos: 95
# Tempo médio de espera (min): 38.79
# Tempo médio de consulta (min): 16.43
# Tempo médio no sistema (min): 55.22
# Tamanho médio da fila: 7.15 | Máx: 14
# Ocupação média: 0.972
# Ocupação por médico (%):
#   m0: 89.35%
#   m1: 87.33%
#   m2: 95.69%
# Métricas por médico:
#   m0: consultas=22 | ocup=89.35% | tm_consulta=23.28 min | t_ocup=512.12 min
#   m1: consultas=39 | ocup=87.33% | tm_consulta=12.83 min | t_ocup=500.53 min
#   m2: consultas=34 | ocup=95.69% | tm_consulta=16.13 min | t_ocup=548.44 min
# Doentes atendidos: 86
# Tempo médio de espera (min): 22.05
# Tempo médio de consulta (min): 17.26
# Tempo médio no sistema (min): 39.31
# Tamanho médio da fila: 3.58 | Máx: 9
# Ocupação média: 0.953
# Ocupação por médico (%):
#   m0: 96.64%
#   m1: 93.35%
#   m2: 89.84%
# Métricas por médico:
#   m0: consultas=30 | ocup=96.64% | tm_consulta=17.08 min | t_ocup=512.51 min
#   m1: consultas=26 | ocup=93.35% | tm_consulta=19.04 min | t_ocup=495.06 min
#   m2: consultas=30 | ocup=89.84% | tm_consulta=15.88 min | t_ocup=476.41 min
# Doentes atendidos: 83
# Tempo médio de espera (min): 3.75
# Tempo médio de consulta (min): 11.99
# Tempo médio no sistema (min): 15.74
# Tamanho médio da fila: 0.88 | Máx: 5
# Ocupação média: 0.721
# Ocupação por médico (%):
#   m0: 71.15%
#   m1: 69.27%
#   m2: 44.7%
# Métricas por médico:
#   m0: consultas=29 | ocup=71.15% | tm_consulta=13.19 min | t_ocup=382.62 min
#   m1: consultas=34 | ocup=69.27% | tm_consulta=10.96 min | t_ocup=372.55 min
#   m2: consultas=20 | ocup=44.70% | tm_consulta=12.02 min | t_ocup=240.37 min
# Doentes atendidos: 92
# Tempo médio de espera (min): 24.55
# Tempo médio de consulta (min): 15.24
# Tempo médio no sistema (min): 39.79
# Tamanho médio da fila: 4.68 | Máx: 11
# Ocupação média: 0.955
# Ocupação por médico (%):
#   m0: 93.46%
#   m1: 96.08%
#   m2: 86.12%
# Métricas por médico:
#   m0: consultas=32 | ocup=93.46% | tm_consulta=14.86 min | t_ocup=475.41 min
#   m1: consultas=34 | ocup=96.08% | tm_consulta=14.37 min | t_ocup=488.72 min
#   m2: consultas=26 | ocup=86.12% | tm_consulta=16.85 min | t_ocup=438.06 min
# Doentes atendidos: 96
# Tempo médio de espera (min): 60.32
# Tempo médio de consulta (min): 18.2
# Tempo médio no sistema (min): 78.52
# Tamanho médio da fila: 9.93 | Máx: 19
# Ocupação média: 0.964
# Ocupação por médico (%):
#   m0: 96.61%
#   m1: 93.6%
#   m2: 95.17%
# Métricas por médico:
#   m0: consultas=30 | ocup=96.61% | tm_consulta=19.71 min | t_ocup=591.34 min
#   m1: consultas=34 | ocup=93.60% | tm_consulta=16.85 min | t_ocup=572.93 min
#   m2: consultas=32 | ocup=95.17% | tm_consulta=18.20 min | t_ocup=582.53 min
# Doentes atendidos: 82
# Tempo médio de espera (min): 14.16
# Tempo médio de consulta (min): 16.03
# Tempo médio no sistema (min): 30.19
# Tamanho médio da fila: 2.43 | Máx: 10
# Ocupação média: 0.929
# Ocupação por médico (%):
#   m0: 92.09%
#   m1: 86.1%
#   m2: 87.36%
# Métricas por médico:
#   m0: consultas=24 | ocup=92.09% | tm_consulta=19.00 min | t_ocup=455.92 min
#   m1: consultas=25 | ocup=86.10% | tm_consulta=17.05 min | t_ocup=426.24 min
#   m2: consultas=33 | ocup=87.36% | tm_consulta=13.11 min | t_ocup=432.48 min
# Doentes atendidos: 86
# Tempo médio de espera (min): 9.16
# Tempo médio de consulta (min): 12.66
# Tempo médio no sistema (min): 21.82
# Tamanho médio da fila: 2.15 | Máx: 9
# Ocupação média: 0.841
# Ocupação por médico (%):
#   m0: 79.11%
#   m1: 81.88%
#   m2: 65.46%
# Métricas por médico:
#   m0: consultas=38 | ocup=79.11% | tm_consulta=10.01 min | t_ocup=380.33 min
#   m1: consultas=24 | ocup=81.88% | tm_consulta=16.40 min | t_ocup=393.65 min
#   m2: consultas=24 | ocup=65.46% | tm_consulta=13.11 min | t_ocup=314.69 min
# Doentes atendidos: 93
# Tempo médio de espera (min): 11.57
# Tempo médio de consulta (min): 14.2
# Tempo médio no sistema (min): 25.77
# Tamanho médio da fila: 1.89 | Máx: 9
# Ocupação média: 0.866
# Ocupação por médico (%):
#   m0: 84.07%
#   m1: 82.84%
#   m2: 76.2%
# Métricas por médico:
#   m0: consultas=39 | ocup=84.07% | tm_consulta=11.71 min | t_ocup=456.82 min
#   m1: consultas=28 | ocup=82.84% | tm_consulta=16.08 min | t_ocup=450.17 min
#   m2: consultas=26 | ocup=76.20% | tm_consulta=15.93 min | t_ocup=414.05 min
# Doentes atendidos: 93
# Tempo médio de espera (min): 28.54
# Tempo médio de consulta (min): 16.3
# Tempo médio no sistema (min): 44.84
# Tamanho médio da fila: 4.97 | Máx: 14
# Ocupação média: 0.889
# Ocupação por médico (%):
#   m0: 93.31%
#   m1: 83.58%
#   m2: 82.38%
# Métricas por médico:
#   m0: consultas=25 | ocup=93.31% | tm_consulta=21.82 min | t_ocup=545.59 min
#   m1: consultas=42 | ocup=83.58% | tm_consulta=11.64 min | t_ocup=488.72 min
#   m2: consultas=26 | ocup=82.38% | tm_consulta=18.53 min | t_ocup=481.66 min
# Doentes atendidos: 99
# Tempo médio de espera (min): 37.02
# Tempo médio de consulta (min): 14.88
# Tempo médio no sistema (min): 51.91
# Tamanho médio da fila: 7.76 | Máx: 15
# Ocupação média: 0.968
# Ocupação por médico (%):
#   m0: 97.44%
#   m1: 93.88%
#   m2: 92.38%
# Métricas por médico:
#   m0: consultas=41 | ocup=97.44% | tm_consulta=12.34 min | t_ocup=506.05 min
#   m1: consultas=30 | ocup=93.88% | tm_consulta=16.25 min | t_ocup=487.58 min
#   m2: consultas=28 | ocup=92.38% | tm_consulta=17.14 min | t_ocup=479.80 min
# Doentes atendidos: 106
# Tempo médio de espera (min): 61.13
# Tempo médio de consulta (min): 17.32
# Tempo médio no sistema (min): 78.44
# Tamanho médio da fila: 11.06 | Máx: 27
# Ocupação média: 0.986
# Ocupação por médico (%):
#   m0: 97.32%
#   m1: 98.54%
#   m2: 98.71%
# Métricas por médico:
#   m0: consultas=35 | ocup=97.32% | tm_consulta=17.33 min | t_ocup=606.48 min
#   m1: consultas=50 | ocup=98.54% | tm_consulta=12.28 min | t_ocup=614.07 min
#   m2: consultas=21 | ocup=98.71% | tm_consulta=29.29 min | t_ocup=615.10 min
# Doentes atendidos: 102
# Tempo médio de espera (min): 22.75
# Tempo médio de consulta (min): 14.01
# Tempo médio no sistema (min): 36.77
# Tamanho médio da fila: 4.51 | Máx: 11
# Ocupação média: 0.951
# Ocupação por médico (%):
#   m0: 96.5%
#   m1: 92.69%
#   m2: 93.45%
# Métricas por médico:
#   m0: consultas=28 | ocup=96.50% | tm_consulta=17.43 min | t_ocup=487.97 min
#   m1: consultas=35 | ocup=92.69% | tm_consulta=13.39 min | t_ocup=468.69 min
#   m2: consultas=39 | ocup=93.45% | tm_consulta=12.12 min | t_ocup=472.54 min
# Doentes atendidos: 93
# Tempo médio de espera (min): 115.44
# Tempo médio de consulta (min): 18.07
# Tempo médio no sistema (min): 133.51
# Tamanho médio da fila: 18.79 | Máx: 35
# Ocupação média: 0.971
# Ocupação por médico (%):
#   m0: 97.57%
#   m1: 96.18%
#   m2: 94.15%
# Métricas por médico:
#   m0: consultas=30 | ocup=97.57% | tm_consulta=18.99 min | t_ocup=569.61 min
#   m1: consultas=33 | ocup=96.18% | tm_consulta=17.01 min | t_ocup=561.49 min
#   m2: consultas=30 | ocup=94.15% | tm_consulta=18.32 min | t_ocup=549.60 min
# Doentes atendidos: 120
# Tempo médio de espera (min): 32.68
# Tempo médio de consulta (min): 12.67
# Tempo médio no sistema (min): 45.35
# Tamanho médio da fila: 7.69 | Máx: 23
# Ocupação média: 0.903
# Ocupação por médico (%):
#   m0: 84.92%
#   m1: 86.83%
#   m2: 86.34%
# Métricas por médico:
#   m0: consultas=41 | ocup=84.92% | tm_consulta=12.20 min | t_ocup=500.14 min
#   m1: consultas=44 | ocup=86.83% | tm_consulta=11.62 min | t_ocup=511.35 min
#   m2: consultas=35 | ocup=86.34% | tm_consulta=14.53 min | t_ocup=508.48 min
# Doentes atendidos: 69
# Tempo médio de espera (min): 4.7
# Tempo médio de consulta (min): 16.44
# Tempo médio no sistema (min): 21.14
# Tamanho médio da fila: 0.83 | Máx: 5
# Ocupação média: 0.787
# Ocupação por médico (%):
#   m0: 75.06%
#   m1: 70.64%
#   m2: 72.6%
# Métricas por médico:
#   m0: consultas=24 | ocup=75.06% | tm_consulta=16.25 min | t_ocup=390.11 min
#   m1: consultas=23 | ocup=70.64% | tm_consulta=15.96 min | t_ocup=367.12 min
#   m2: consultas=22 | ocup=72.60% | tm_consulta=17.15 min | t_ocup=377.33 min
# Doentes atendidos: 79
# Tempo médio de espera (min): 5.25
# Tempo médio de consulta (min): 14.84
# Tempo médio no sistema (min): 20.09
# Tamanho médio da fila: 0.97 | Máx: 6
# Ocupação média: 0.787
# Ocupação por médico (%):
#   m0: 82.68%
#   m1: 70.63%
#   m2: 67.08%
# Métricas por médico:
#   m0: consultas=26 | ocup=82.68% | tm_consulta=16.92 min | t_ocup=439.94 min
#   m1: consultas=31 | ocup=70.63% | tm_consulta=12.12 min | t_ocup=375.81 min
#   m2: consultas=22 | ocup=67.08% | tm_consulta=16.22 min | t_ocup=356.95 min
# Doentes atendidos: 105
# Tempo médio de espera (min): 22.79
# Tempo médio de consulta (min): 14.19
# Tempo médio no sistema (min): 36.98
# Tamanho médio da fila: 4.83 | Máx: 11
# Ocupação média: 0.984
# Ocupação por médico (%):
#   m0: 93.67%
#   m1: 98.46%
#   m2: 94.79%
# Métricas por médico:
#   m0: consultas=41 | ocup=93.67% | tm_consulta=11.86 min | t_ocup=486.36 min
#   m1: consultas=31 | ocup=98.46% | tm_consulta=16.49 min | t_ocup=511.20 min
#   m2: consultas=33 | ocup=94.79% | tm_consulta=14.91 min | t_ocup=492.15 min
# Doentes atendidos: 92
# Tempo médio de espera (min): 25.46
# Tempo médio de consulta (min): 15.68
# Tempo médio no sistema (min): 41.14
# Tamanho médio da fila: 4.95 | Máx: 13
# Ocupação média: 0.967
# Ocupação por médico (%):
#   m0: 98.75%
#   m1: 90.12%
#   m2: 88.84%
# Métricas por médico:
#   m0: consultas=20 | ocup=98.75% | tm_consulta=25.65 min | t_ocup=512.93 min
#   m1: consultas=33 | ocup=90.12% | tm_consulta=14.18 min | t_ocup=468.06 min
#   m2: consultas=39 | ocup=88.84% | tm_consulta=11.83 min | t_ocup=461.41 min
# Doentes atendidos: 99
# Tempo médio de espera (min): 49.52
# Tempo médio de consulta (min): 17.75
# Tempo médio no sistema (min): 67.28
# Tamanho médio da fila: 8.91 | Máx: 17
# Ocupação média: 0.978
# Ocupação por médico (%):
#   m0: 98.94%
#   m1: 80.5%
#   m2: 78.36%
# Métricas por médico:
#   m0: consultas=36 | ocup=98.94% | tm_consulta=18.73 min | t_ocup=674.45 min
#   m1: consultas=30 | ocup=80.50% | tm_consulta=18.29 min | t_ocup=548.77 min
#   m2: consultas=33 | ocup=78.36% | tm_consulta=16.19 min | t_ocup=534.14 min
# Doentes atendidos: 100
# Tempo médio de espera (min): 6.92
# Tempo médio de consulta (min): 12.18
# Tempo médio no sistema (min): 19.1
# Tamanho médio da fila: 1.74 | Máx: 10
# Ocupação média: 0.842
# Ocupação por médico (%):
#   m0: 81.55%
#   m1: 79.83%
#   m2: 75.52%
# Métricas por médico:
#   m0: consultas=36 | ocup=81.55% | tm_consulta=11.64 min | t_ocup=419.20 min
#   m1: consultas=35 | ocup=79.83% | tm_consulta=11.72 min | t_ocup=410.35 min
#   m2: consultas=29 | ocup=75.52% | tm_consulta=13.39 min | t_ocup=388.22 min
# Doentes atendidos: 82
# Tempo médio de espera (min): 13.13
# Tempo médio de consulta (min): 15.26
# Tempo médio no sistema (min): 28.39
# Tamanho médio da fila: 2.33 | Máx: 8
# Ocupação média: 0.866
# Ocupação por médico (%):
#   m0: 86.57%
#   m1: 74.25%
#   m2: 65.27%
# Métricas por médico:
#   m0: consultas=30 | ocup=86.57% | tm_consulta=15.98 min | t_ocup=479.28 min
#   m1: consultas=25 | ocup=74.25% | tm_consulta=16.44 min | t_ocup=411.05 min
#   m2: consultas=27 | ocup=65.27% | tm_consulta=13.38 min | t_ocup=361.33 min
# Doentes atendidos: 86
# Tempo médio de espera (min): 42.77
# Tempo médio de consulta (min): 19.48
# Tempo médio no sistema (min): 62.25
# Tamanho médio da fila: 6.77 | Máx: 14
# Ocupação média: 0.953
# Ocupação por médico (%):
#   m0: 99.41%
#   m1: 81.3%
#   m2: 79.58%
# Métricas por médico:
#   m0: consultas=33 | ocup=99.41% | tm_consulta=19.39 min | t_ocup=639.91 min
#   m1: consultas=20 | ocup=81.30% | tm_consulta=26.17 min | t_ocup=523.31 min
#   m2: consultas=33 | ocup=79.58% | tm_consulta=15.52 min | t_ocup=512.25 min
# Doentes atendidos: 96
# Tempo médio de espera (min): 11.81
# Tempo médio de consulta (min): 13.65
# Tempo médio no sistema (min): 25.46
# Tamanho médio da fila: 2.41 | Máx: 10
# Ocupação média: 0.878
# Ocupação por médico (%):
#   m0: 89.35%
#   m1: 81.5%
#   m2: 77.42%
# Métricas por médico:
#   m0: consultas=37 | ocup=89.35% | tm_consulta=12.75 min | t_ocup=471.67 min
#   m1: consultas=33 | ocup=81.50% | tm_consulta=13.04 min | t_ocup=430.19 min
#   m2: consultas=26 | ocup=77.42% | tm_consulta=15.72 min | t_ocup=408.68 min
# Doentes atendidos: 103
# Tempo médio de espera (min): 25.39
# Tempo médio de consulta (min): 14.11
# Tempo médio no sistema (min): 39.5
# Tamanho médio da fila: 5.25 | Máx: 13
# Ocupação média: 0.966
# Ocupação por médico (%):
#   m0: 93.33%
#   m1: 92.97%
#   m2: 86.08%
# Métricas por médico:
#   m0: consultas=27 | ocup=93.33% | tm_consulta=18.44 min | t_ocup=497.98 min
#   m1: consultas=31 | ocup=92.97% | tm_consulta=16.00 min | t_ocup=496.03 min
#   m2: consultas=45 | ocup=86.08% | tm_consulta=10.21 min | t_ocup=459.28 min
# Doentes atendidos: 94
# Tempo médio de espera (min): 25.36
# Tempo médio de consulta (min): 15.53
# Tempo médio no sistema (min): 40.89
# Tamanho médio da fila: 5.12 | Máx: 12
# Ocupação média: 0.94
# Ocupação por médico (%):
#   m0: 94.68%
#   m1: 90.56%
#   m2: 88.82%
# Métricas por médico:
#   m0: consultas=35 | ocup=94.68% | tm_consulta=14.41 min | t_ocup=504.42 min
#   m1: consultas=30 | ocup=90.56% | tm_consulta=16.08 min | t_ocup=482.49 min
#   m2: consultas=29 | ocup=88.82% | tm_consulta=16.32 min | t_ocup=473.20 min
# Doentes atendidos: 108
# Tempo médio de espera (min): 62.26
# Tempo médio de consulta (min): 17.15
# Tempo médio no sistema (min): 79.41
# Tamanho médio da fila: 9.51 | Máx: 30
# Ocupação média: 0.934
# Ocupação por médico (%):
#   m0: 92.58%
#   m1: 94.18%
#   m2: 89.86%
# Métricas por médico:
#   m0: consultas=39 | ocup=92.58% | tm_consulta=15.90 min | t_ocup=619.95 min
#   m1: consultas=36 | ocup=94.18% | tm_consulta=17.52 min | t_ocup=630.70 min
#   m2: consultas=33 | ocup=89.86% | tm_consulta=18.23 min | t_ocup=601.74 min
# Doentes atendidos: 99
# Tempo médio de espera (min): 20.22
# Tempo médio de consulta (min): 13.72
# Tempo médio no sistema (min): 33.94
# Tamanho médio da fila: 4.49 | Máx: 10
# Ocupação média: 0.939
# Ocupação por médico (%):
#   m0: 90.98%
#   m1: 93.21%
#   m2: 85.38%
# Métricas por médico:
#   m0: consultas=36 | ocup=90.98% | tm_consulta=12.73 min | t_ocup=458.40 min
#   m1: consultas=33 | ocup=93.21% | tm_consulta=14.23 min | t_ocup=469.62 min
#   m2: consultas=30 | ocup=85.38% | tm_consulta=14.34 min | t_ocup=430.18 min
# Doentes atendidos: 95
# Tempo médio de espera (min): 20.05
# Tempo médio de consulta (min): 14.63
# Tempo médio no sistema (min): 34.68
# Tamanho médio da fila: 3.82 | Máx: 13
# Ocupação média: 0.893
# Ocupação por médico (%):
#   m0: 90.58%
#   m1: 85.16%
#   m2: 78.79%
# Métricas por médico:
#   m0: consultas=39 | ocup=90.58% | tm_consulta=12.68 min | t_ocup=494.67 min
#   m1: consultas=35 | ocup=85.16% | tm_consulta=13.29 min | t_ocup=465.06 min
#   m2: consultas=21 | ocup=78.79% | tm_consulta=20.49 min | t_ocup=430.30 min
# Doentes atendidos: 95
# Tempo médio de espera (min): 13.83
# Tempo médio de consulta (min): 13.43
# Tempo médio no sistema (min): 27.26
# Tamanho médio da fila: 3.13 | Máx: 10
# Ocupação média: 0.937
# Ocupação por médico (%):
#   m0: 91.33%
#   m1: 89.83%
#   m2: 87.34%
# Métricas por médico:
#   m0: consultas=23 | ocup=91.33% | tm_consulta=18.87 min | t_ocup=434.00 min
#   m1: consultas=32 | ocup=89.83% | tm_consulta=13.34 min | t_ocup=426.85 min
#   m2: consultas=40 | ocup=87.34% | tm_consulta=10.38 min | t_ocup=415.02 min
# Doentes atendidos: 90
# Tempo médio de espera (min): 28.58
# Tempo médio de consulta (min): 14.61
# Tempo médio no sistema (min): 43.18
# Tamanho médio da fila: 5.94 | Máx: 14
# Ocupação média: 0.965
# Ocupação por médico (%):
#   m0: 94.99%
#   m1: 95.97%
#   m2: 92.52%
# Métricas por médico:
#   m0: consultas=34 | ocup=94.99% | tm_consulta=12.96 min | t_ocup=440.54 min
#   m1: consultas=26 | ocup=95.97% | tm_consulta=17.12 min | t_ocup=445.11 min
#   m2: consultas=30 | ocup=92.52% | tm_consulta=14.30 min | t_ocup=429.08 min
# Doentes atendidos: 91
# Tempo médio de espera (min): 19.06
# Tempo médio de consulta (min): 15.91
# Tempo médio no sistema (min): 34.97
# Tamanho médio da fila: 3.73 | Máx: 13
# Ocupação média: 0.949
# Ocupação por médico (%):
#   m0: 90.65%
#   m1: 96.52%
#   m2: 87.69%
# Métricas por médico:
#   m0: consultas=32 | ocup=90.65% | tm_consulta=14.92 min | t_ocup=477.57 min
#   m1: consultas=27 | ocup=96.52% | tm_consulta=18.83 min | t_ocup=508.51 min
#   m2: consultas=32 | ocup=87.69% | tm_consulta=14.44 min | t_ocup=461.98 min
# Doentes atendidos: 109
# Tempo médio de espera (min): 24.48
# Tempo médio de consulta (min): 13.8
# Tempo médio no sistema (min): 38.28
# Tamanho médio da fila: 5.44 | Máx: 16
# Ocupação média: 0.953
# Ocupação por médico (%):
#   m0: 92.67%
#   m1: 95.23%
#   m2: 90.17%
# Métricas por médico:
#   m0: consultas=40 | ocup=92.67% | tm_consulta=12.53 min | t_ocup=501.39 min
#   m1: consultas=30 | ocup=95.23% | tm_consulta=17.17 min | t_ocup=515.23 min
#   m2: consultas=39 | ocup=90.17% | tm_consulta=12.51 min | t_ocup=487.87 min
# Doentes atendidos: 116
# Tempo médio de espera (min): 82.07
# Tempo médio de consulta (min): 15.44
# Tempo médio no sistema (min): 97.51
# Tamanho médio da fila: 17.25 | Máx: 28
# Ocupação média: 0.986
# Ocupação por médico (%):
#   m0: 98.11%
#   m1: 97.25%
#   m2: 97.15%
# Métricas por médico:
#   m0: consultas=37 | ocup=98.11% | tm_consulta=16.24 min | t_ocup=600.93 min
#   m1: consultas=35 | ocup=97.25% | tm_consulta=17.02 min | t_ocup=595.66 min
#   m2: consultas=44 | ocup=97.15% | tm_consulta=13.52 min | t_ocup=595.03 min
# Doentes atendidos: 99
# Tempo médio de espera (min): 7.72
# Tempo médio de consulta (min): 13.03
# Tempo médio no sistema (min): 20.76
# Tamanho médio da fila: 1.75 | Máx: 8
# Ocupação média: 0.872
# Ocupação por médico (%):
#   m0: 91.05%
#   m1: 79.59%
#   m2: 71.42%
# Métricas por médico:
#   m0: consultas=30 | ocup=91.05% | tm_consulta=16.18 min | t_ocup=485.37 min
#   m1: consultas=36 | ocup=79.59% | tm_consulta=11.78 min | t_ocup=424.26 min
#   m2: consultas=33 | ocup=71.42% | tm_consulta=11.54 min | t_ocup=380.73 min
# Doentes atendidos: 82
# Tempo médio de espera (min): 14.02
# Tempo médio de consulta (min): 14.37
# Tempo médio no sistema (min): 28.38
# Tamanho médio da fila: 2.66 | Máx: 9
# Ocupação média: 0.868
# Ocupação por médico (%):
#   m0: 84.36%
#   m1: 82.78%
#   m2: 70.56%
# Métricas por médico:
#   m0: consultas=33 | ocup=84.36% | tm_consulta=12.67 min | t_ocup=418.07 min
#   m1: consultas=24 | ocup=82.78% | tm_consulta=17.09 min | t_ocup=410.25 min
#   m2: consultas=25 | ocup=70.56% | tm_consulta=13.99 min | t_ocup=349.67 min
# Doentes atendidos: 100
# Tempo médio de espera (min): 34.44
# Tempo médio de consulta (min): 14.67
# Tempo médio no sistema (min): 49.11
# Tamanho médio da fila: 7.25 | Máx: 23
# Ocupação média: 0.905
# Ocupação por médico (%):
#   m0: 90.09%
#   m1: 83.85%
#   m2: 80.99%
# Métricas por médico:
#   m0: consultas=32 | ocup=90.09% | tm_consulta=16.20 min | t_ocup=518.50 min
#   m1: consultas=36 | ocup=83.85% | tm_consulta=13.41 min | t_ocup=482.60 min
#   m2: consultas=32 | ocup=80.99% | tm_consulta=14.57 min | t_ocup=466.10 min
# Doentes atendidos: 92
# Tempo médio de espera (min): 6.81
# Tempo médio de consulta (min): 15.15
# Tempo médio no sistema (min): 21.96
# Tamanho médio da fila: 1.54 | Máx: 7
# Ocupação média: 0.915
# Ocupação por médico (%):
#   m0: 94.36%
#   m1: 81.02%
#   m2: 82.7%
# Métricas por médico:
#   m0: consultas=33 | ocup=94.36% | tm_consulta=15.44 min | t_ocup=509.50 min
#   m1: consultas=35 | ocup=81.02% | tm_consulta=12.50 min | t_ocup=437.50 min
#   m2: consultas=24 | ocup=82.70% | tm_consulta=18.61 min | t_ocup=446.54 min
# Doentes atendidos: 100
# Tempo médio de espera (min): 19.56
# Tempo médio de consulta (min): 15.23
# Tempo médio no sistema (min): 34.8
# Tamanho médio da fila: 3.78 | Máx: 13
# Ocupação média: 0.937
# Ocupação por médico (%):
#   m0: 91.26%
#   m1: 91.68%
#   m2: 87.53%
# Métricas por médico:
#   m0: consultas=33 | ocup=91.26% | tm_consulta=15.58 min | t_ocup=514.00 min
#   m1: consultas=30 | ocup=91.68% | tm_consulta=17.21 min | t_ocup=516.36 min
#   m2: consultas=37 | ocup=87.53% | tm_consulta=13.32 min | t_ocup=493.01 min
# Doentes atendidos: 104
# Tempo médio de espera (min): 69.74
# Tempo médio de consulta (min): 16.33
# Tempo médio no sistema (min): 86.08
# Tamanho médio da fila: 13.7 | Máx: 26
# Ocupação média: 0.95
# Ocupação por médico (%):
#   m0: 95.64%
#   m1: 88.7%
#   m2: 87.99%
# Métricas por médico:
#   m0: consultas=36 | ocup=95.64% | tm_consulta=16.57 min | t_ocup=596.57 min
#   m1: consultas=39 | ocup=88.70% | tm_consulta=14.19 min | t_ocup=553.30 min
#   m2: consultas=29 | ocup=87.99% | tm_consulta=18.93 min | t_ocup=548.90 min
# Doentes atendidos: 85
# Tempo médio de espera (min): 7.04
# Tempo médio de consulta (min): 13.13
# Tempo médio no sistema (min): 20.18
# Tamanho médio da fila: 1.46 | Máx: 8
# Ocupação média: 0.829
# Ocupação por médico (%):
#   m0: 87.38%
#   m1: 76.23%
#   m2: 68.78%
# Métricas por médico:
#   m0: consultas=27 | ocup=87.38% | tm_consulta=15.55 min | t_ocup=419.80 min
#   m1: consultas=25 | ocup=76.23% | tm_consulta=14.65 min | t_ocup=366.23 min
#   m2: consultas=33 | ocup=68.78% | tm_consulta=10.01 min | t_ocup=330.42 min
# Doentes atendidos: 96
# Tempo médio de espera (min): 26.89
# Tempo médio de consulta (min): 14.27
# Tempo médio no sistema (min): 41.16
# Tamanho médio da fila: 5.56 | Máx: 13
# Ocupação média: 0.957
# Ocupação por médico (%):
#   m0: 86.24%
#   m1: 88.67%
#   m2: 91.53%
# Métricas por médico:
#   m0: consultas=34 | ocup=86.24% | tm_consulta=13.04 min | t_ocup=443.40 min
#   m1: consultas=35 | ocup=88.67% | tm_consulta=13.02 min | t_ocup=455.87 min
#   m2: consultas=27 | ocup=91.53% | tm_consulta=17.43 min | t_ocup=470.56 min
# Doentes atendidos: 91
# Tempo médio de espera (min): 40.63
# Tempo médio de consulta (min): 16.02
# Tempo médio no sistema (min): 56.65
# Tamanho médio da fila: 7.31 | Máx: 13
# Ocupação média: 0.978
# Ocupação por médico (%):
#   m0: 99.79%
#   m1: 96.19%
#   m2: 94.62%
# Métricas por médico:
#   m0: consultas=37 | ocup=99.79% | tm_consulta=13.53 min | t_ocup=500.73 min
#   m1: consultas=26 | ocup=96.19% | tm_consulta=18.56 min | t_ocup=482.64 min
#   m2: consultas=28 | ocup=94.62% | tm_consulta=16.96 min | t_ocup=474.77 min
# Doentes atendidos: 105
# Tempo médio de espera (min): 37.06
# Tempo médio de consulta (min): 13.8
# Tempo médio no sistema (min): 50.86
# Tamanho médio da fila: 8.05 | Máx: 26
# Ocupação média: 0.89
# Ocupação por médico (%):
#   m0: 89.2%
#   m1: 80.19%
#   m2: 76.29%
# Métricas por médico:
#   m0: consultas=42 | ocup=89.20% | tm_consulta=12.52 min | t_ocup=525.97 min
#   m1: consultas=33 | ocup=80.19% | tm_consulta=14.33 min | t_ocup=472.84 min
#   m2: consultas=30 | ocup=76.29% | tm_consulta=14.99 min | t_ocup=449.83 min
# Doentes atendidos: 95
# Tempo médio de espera (min): 7.62
# Tempo médio de consulta (min): 13.11
# Tempo médio no sistema (min): 20.73
# Tamanho médio da fila: 1.54 | Máx: 7
# Ocupação média: 0.898
# Ocupação por médico (%):
#   m0: 83.42%
#   m1: 74.42%
#   m2: 88.44%
# Métricas por médico:
#   m0: consultas=33 | ocup=83.42% | tm_consulta=12.78 min | t_ocup=421.82 min
#   m1: consultas=37 | ocup=74.42% | tm_consulta=10.17 min | t_ocup=376.31 min
#   m2: consultas=25 | ocup=88.44% | tm_consulta=17.89 min | t_ocup=447.21 min
# Doentes atendidos: 103
# Tempo médio de espera (min): 39.63
# Tempo médio de consulta (min): 16.34
# Tempo médio no sistema (min): 55.96
# Tamanho médio da fila: 6.86 | Máx: 19
# Ocupação média: 0.969
# Ocupação por médico (%):
#   m0: 92.29%
#   m1: 95.48%
#   m2: 91.93%
# Métricas por médico:
#   m0: consultas=35 | ocup=92.29% | tm_consulta=15.86 min | t_ocup=555.17 min
#   m1: consultas=40 | ocup=95.48% | tm_consulta=14.36 min | t_ocup=574.41 min
#   m2: consultas=28 | ocup=91.93% | tm_consulta=19.75 min | t_ocup=553.04 min
# Doentes atendidos: 89
# Tempo médio de espera (min): 22.97
# Tempo médio de consulta (min): 16.54
# Tempo médio no sistema (min): 39.51
# Tamanho médio da fila: 4.11 | Máx: 13
# Ocupação média: 0.912
# Ocupação por médico (%):
#   m0: 82.17%
#   m1: 74.54%
#   m2: 85.77%
# Métricas por médico:
#   m0: consultas=37 | ocup=82.17% | tm_consulta=13.48 min | t_ocup=498.93 min
#   m1: consultas=31 | ocup=74.54% | tm_consulta=14.60 min | t_ocup=452.58 min
#   m2: consultas=21 | ocup=85.77% | tm_consulta=24.80 min | t_ocup=520.76 min
# Doentes atendidos: 111
# Tempo médio de espera (min): 54.64
# Tempo médio de consulta (min): 14.33
# Tempo médio no sistema (min): 68.98
# Tamanho médio da fila: 10.26 | Máx: 28
# Ocupação média: 0.926
# Ocupação por médico (%):
#   m0: 94.87%
#   m1: 86.1%
#   m2: 88.69%
# Métricas por médico:
#   m0: consultas=38 | ocup=94.87% | tm_consulta=14.73 min | t_ocup=559.67 min
#   m1: consultas=37 | ocup=86.10% | tm_consulta=13.73 min | t_ocup=507.89 min
#   m2: consultas=36 | ocup=88.69% | tm_consulta=14.53 min | t_ocup=523.19 min
# Doentes atendidos: 134
# Tempo médio de espera (min): 112.46
# Tempo médio de consulta (min): 15.0
# Tempo médio no sistema (min): 127.46
# Tamanho médio da fila: 24.88 | Máx: 43
# Ocupação média: 0.989
# Ocupação por médico (%):
#   m0: 91.48%
#   m1: 93.06%
#   m2: 99.05%
# Métricas por médico:
#   m0: consultas=45 | ocup=91.48% | tm_consulta=14.41 min | t_ocup=648.46 min
#   m1: consultas=49 | ocup=93.06% | tm_consulta=13.46 min | t_ocup=659.63 min
#   m2: consultas=40 | ocup=99.05% | tm_consulta=17.55 min | t_ocup=702.10 min
# Doentes atendidos: 109
# Tempo médio de espera (min): 60.34
# Tempo médio de consulta (min): 14.82
# Tempo médio no sistema (min): 75.16
# Tamanho médio da fila: 12.3 | Máx: 29
# Ocupação média: 0.963
# Ocupação por médico (%):
#   m0: 95.48%
#   m1: 94.44%
#   m2: 92.29%
# Métricas por médico:
#   m0: consultas=41 | ocup=95.48% | tm_consulta=13.33 min | t_ocup=546.60 min
#   m1: consultas=39 | ocup=94.44% | tm_consulta=13.86 min | t_ocup=540.64 min
#   m2: consultas=29 | ocup=92.29% | tm_consulta=18.22 min | t_ocup=528.36 min
# Doentes atendidos: 98
# Tempo médio de espera (min): 29.24
# Tempo médio de consulta (min): 14.59
# Tempo médio no sistema (min): 43.84
# Tamanho médio da fila: 6.03 | Máx: 16
# Ocupação média: 0.934
# Ocupação por médico (%):
#   m0: 90.51%
#   m1: 93.01%
#   m2: 91.08%
# Métricas por médico:
#   m0: consultas=29 | ocup=90.51% | tm_consulta=16.26 min | t_ocup=471.46 min
#   m1: consultas=33 | ocup=93.01% | tm_consulta=14.68 min | t_ocup=484.45 min
#   m2: consultas=36 | ocup=91.08% | tm_consulta=13.18 min | t_ocup=474.39 min
# Doentes atendidos: 108
# Tempo médio de espera (min): 64.49
# Tempo médio de consulta (min): 18.21
# Tempo médio no sistema (min): 82.7
# Tamanho médio da fila: 10.35 | Máx: 26
# Ocupação média: 0.975
# Ocupação por médico (%):
#   m0: 98.08%
#   m1: 96.55%
#   m2: 94.84%
# Métricas por médico:
#   m0: consultas=35 | ocup=98.08% | tm_consulta=19.04 min | t_ocup=666.45 min
#   m1: consultas=42 | ocup=96.55% | tm_consulta=15.62 min | t_ocup=656.10 min
#   m2: consultas=31 | ocup=94.84% | tm_consulta=20.79 min | t_ocup=644.48 min
# Doentes atendidos: 98
# Tempo médio de espera (min): 18.91
# Tempo médio de consulta (min): 13.81
# Tempo médio no sistema (min): 32.71
# Tamanho médio da fila: 4.1 | Máx: 14
# Ocupação média: 0.934
# Ocupação por médico (%):
#   m0: 92.45%
#   m1: 90.09%
#   m2: 83.29%
# Métricas por médico:
#   m0: consultas=34 | ocup=92.45% | tm_consulta=13.84 min | t_ocup=470.53 min
#   m1: consultas=38 | ocup=90.09% | tm_consulta=12.07 min | t_ocup=458.48 min
#   m2: consultas=26 | ocup=83.29% | tm_consulta=16.30 min | t_ocup=423.89 min
# Doentes atendidos: 112
# Tempo médio de espera (min): 88.48
# Tempo médio de consulta (min): 16.13
# Tempo médio no sistema (min): 104.61
# Tamanho médio da fila: 15.3 | Máx: 34
# Ocupação média: 0.923
# Ocupação por médico (%):
#   m0: 92.46%
#   m1: 91.11%
#   m2: 90.38%
# Métricas por médico:
#   m0: consultas=40 | ocup=92.46% | tm_consulta=15.25 min | t_ocup=609.86 min
#   m1: consultas=37 | ocup=91.11% | tm_consulta=16.24 min | t_ocup=600.97 min
#   m2: consultas=35 | ocup=90.38% | tm_consulta=17.03 min | t_ocup=596.15 min
# Doentes atendidos: 127
# Tempo médio de espera (min): 127.21
# Tempo médio de consulta (min): 19.48
# Tempo médio no sistema (min): 146.69
# Tamanho médio da fila: 20.05 | Máx: 45
# Ocupação média: 0.967
# Ocupação por médico (%):
#   m0: 98.65%
#   m1: 97.42%
#   m2: 95.08%
# Métricas por médico:
#   m0: consultas=37 | ocup=98.65% | tm_consulta=22.66 min | t_ocup=838.35 min
#   m1: consultas=47 | ocup=97.42% | tm_consulta=17.62 min | t_ocup=827.96 min
#   m2: consultas=43 | ocup=95.08% | tm_consulta=18.79 min | t_ocup=808.00 min
# Doentes atendidos: 132
# Tempo médio de espera (min): 63.23
# Tempo médio de consulta (min): 13.23
# Tempo médio no sistema (min): 76.46
# Tamanho médio da fila: 12.9 | Máx: 34
# Ocupação média: 0.934
# Ocupação por médico (%):
#   m0: 94.38%
#   m1: 94.55%
#   m2: 93.12%
# Métricas por médico:
#   m0: consultas=51 | ocup=94.38% | tm_consulta=11.46 min | t_ocup=584.47 min
#   m1: consultas=47 | ocup=94.55% | tm_consulta=12.46 min | t_ocup=585.52 min
#   m2: consultas=34 | ocup=93.12% | tm_consulta=16.96 min | t_ocup=576.69 min
# Doentes atendidos: 107
# Tempo médio de espera (min): 50.03
# Tempo médio de consulta (min): 16.38
# Tempo médio no sistema (min): 66.41
# Tamanho médio da fila: 9.09 | Máx: 17
# Ocupação média: 0.966
# Ocupação por médico (%):
#   m0: 95.59%
#   m1: 92.2%
#   m2: 93.17%
# Métricas por médico:
#   m0: consultas=34 | ocup=95.59% | tm_consulta=17.54 min | t_ocup=596.23 min
#   m1: consultas=39 | ocup=92.20% | tm_consulta=14.74 min | t_ocup=575.05 min
#   m2: consultas=34 | ocup=93.17% | tm_consulta=17.09 min | t_ocup=581.12 min
# Doentes atendidos: 100
# Tempo médio de espera (min): 45.94
# Tempo médio de consulta (min): 15.43
# Tempo médio no sistema (min): 61.37
# Tamanho médio da fila: 7.96 | Máx: 19
# Ocupação média: 0.948
# Ocupação por médico (%):
#   m0: 94.83%
#   m1: 92.21%
#   m2: 94.48%
# Métricas por médico:
#   m0: consultas=42 | ocup=94.83% | tm_consulta=12.37 min | t_ocup=519.73 min
#   m1: consultas=27 | ocup=92.21% | tm_consulta=18.72 min | t_ocup=505.38 min
#   m2: consultas=31 | ocup=94.48% | tm_consulta=16.70 min | t_ocup=517.84 min
# Doentes atendidos: 116
# Tempo médio de espera (min): 63.64
# Tempo médio de consulta (min): 15.59
# Tempo médio no sistema (min): 79.23
# Tamanho médio da fila: 11.93 | Máx: 27
# Ocupação média: 0.986
# Ocupação por médico (%):
#   m0: 98.82%
#   m1: 96.81%
#   m2: 95.86%
# Métricas por médico:
#   m0: consultas=39 | ocup=98.82% | tm_consulta=15.73 min | t_ocup=613.30 min
#   m1: consultas=23 | ocup=96.81% | tm_consulta=26.12 min | t_ocup=600.79 min
#   m2: consultas=54 | ocup=95.86% | tm_consulta=11.02 min | t_ocup=594.88 min
# Doentes atendidos: 127
# Tempo médio de espera (min): 56.98
# Tempo médio de consulta (min): 13.65
# Tempo médio no sistema (min): 70.63
# Tamanho médio da fila: 11.29 | Máx: 23
# Ocupação média: 0.963
# Ocupação por médico (%):
#   m0: 95.31%
#   m1: 96.36%
#   m2: 92.48%
# Métricas por médico:
#   m0: consultas=36 | ocup=95.31% | tm_consulta=16.15 min | t_ocup=581.52 min
#   m1: consultas=43 | ocup=96.36% | tm_consulta=13.67 min | t_ocup=587.93 min
#   m2: consultas=48 | ocup=92.48% | tm_consulta=11.76 min | t_ocup=564.29 min
# Doentes atendidos: 132
# Tempo médio de espera (min): 95.04
# Tempo médio de consulta (min): 15.89
# Tempo médio no sistema (min): 110.92
# Tamanho médio da fila: 16.81 | Máx: 39
# Ocupação média: 0.971
# Ocupação por médico (%):
#   m0: 96.56%
#   m1: 95.85%
#   m2: 98.01%
# Métricas por médico:
#   m0: consultas=50 | ocup=96.56% | tm_consulta=13.94 min | t_ocup=697.23 min
#   m1: consultas=41 | ocup=95.85% | tm_consulta=16.88 min | t_ocup=692.14 min
#   m2: consultas=41 | ocup=98.01% | tm_consulta=17.26 min | t_ocup=707.68 min
# Doentes atendidos: 97
# Tempo médio de espera (min): 26.8
# Tempo médio de consulta (min): 16.18
# Tempo médio no sistema (min): 42.98
# Tamanho médio da fila: 4.51 | Máx: 14
# Ocupação média: 0.911
# Ocupação por médico (%):
#   m0: 90.59%
#   m1: 90.74%
#   m2: 91.33%
# Métricas por médico:
#   m0: consultas=30 | ocup=90.59% | tm_consulta=17.38 min | t_ocup=521.47 min
#   m1: consultas=30 | ocup=90.74% | tm_consulta=17.41 min | t_ocup=522.33 min
#   m2: consultas=37 | ocup=91.33% | tm_consulta=14.21 min | t_ocup=525.72 min
# Doentes atendidos: 85
# Tempo médio de espera (min): 11.83
# Tempo médio de consulta (min): 14.27
# Tempo médio no sistema (min): 26.1
# Tamanho médio da fila: 2.51 | Máx: 10
# Ocupação média: 0.808
# Ocupação por médico (%):
#   m0: 77.82%
#   m1: 81.47%
#   m2: 57.42%
# Métricas por médico:
#   m0: consultas=28 | ocup=77.82% | tm_consulta=15.55 min | t_ocup=435.53 min
#   m1: consultas=35 | ocup=81.47% | tm_consulta=13.03 min | t_ocup=455.96 min
#   m2: consultas=22 | ocup=57.42% | tm_consulta=14.61 min | t_ocup=321.37 min
# Doentes atendidos: 101
# Tempo médio de espera (min): 6.85
# Tempo médio de consulta (min): 13.58
# Tempo médio no sistema (min): 20.43
# Tamanho médio da fila: 1.37 | Máx: 6
# Ocupação média: 0.893
# Ocupação por médico (%):
#   m0: 89.53%
#   m1: 86.4%
#   m2: 79.86%
# Métricas por médico:
#   m0: consultas=30 | ocup=89.53% | tm_consulta=16.00 min | t_ocup=479.99 min
#   m1: consultas=35 | ocup=86.40% | tm_consulta=13.23 min | t_ocup=463.22 min
#   m2: consultas=36 | ocup=79.86% | tm_consulta=11.89 min | t_ocup=428.14 min
# Doentes atendidos: 84
# Tempo médio de espera (min): 18.51
# Tempo médio de consulta (min): 16.22
# Tempo médio no sistema (min): 34.73
# Tamanho médio da fila: 2.87 | Máx: 13
# Ocupação média: 0.869
# Ocupação por médico (%):
#   m0: 88.35%
#   m1: 85.17%
#   m2: 79.48%
# Métricas por médico:
#   m0: consultas=25 | ocup=88.35% | tm_consulta=19.03 min | t_ocup=475.73 min
#   m1: consultas=36 | ocup=85.17% | tm_consulta=12.74 min | t_ocup=458.61 min
# ...
#   m2: consultas=80 | ocup=99.19% | tm_consulta=13.21 min | t_ocup=1056.42 min
# Doentes atendidos: 220
# Tempo médio de espera (min): 399.42
# Tempo médio de consulta (min): 17.04
# Tempo médio no sistema (min): 416.45
# Tamanho médio da fila: 73.42 | Máx: 138
# Ocupação média: 0.989
# Ocupação por médico (%):
#   m0: 99.36%
#   m1: 97.28%
#   m2: 99.57%
# Métricas por médico:
#   m0: consultas=63 | ocup=99.36% | tm_consulta=19.96 min | t_ocup=1257.41 min
#   m1: consultas=89 | ocup=97.28% | tm_consulta=13.83 min | t_ocup=1231.10 min
#   m2: consultas=68 | ocup=99.57% | tm_consulta=18.53 min | t_ocup=1260.09 min
# Doentes atendidos: 229
# Tempo médio de espera (min): 293.52
# Tempo médio de consulta (min): 14.25
# Tempo médio no sistema (min): 307.77
# Tamanho médio da fila: 64.18 | Máx: 132
# Ocupação média: 0.993
# Ocupação por médico (%):
#   m0: 94.27%
#   m1: 99.77%
#   m2: 92.46%
# Métricas por médico:
#   m0: consultas=71 | ocup=94.27% | tm_consulta=15.13 min | t_ocup=1074.00 min
#   m1: consultas=86 | ocup=99.77% | tm_consulta=13.22 min | t_ocup=1136.64 min
#   m2: consultas=72 | ocup=92.46% | tm_consulta=14.63 min | t_ocup=1053.34 min
# Doentes atendidos: 237
# Tempo médio de espera (min): 324.87
# Tempo médio de consulta (min): 14.65
# Tempo médio no sistema (min): 339.52
# Tamanho médio da fila: 67.38 | Máx: 136
# Ocupação média: 0.989
# Ocupação por médico (%):
#   m0: 98.79%
#   m1: 99.52%
#   m2: 99.14%
# Métricas por médico:
#   m0: consultas=65 | ocup=98.79% | tm_consulta=17.75 min | t_ocup=1153.45 min
#   m1: consultas=85 | ocup=99.52% | tm_consulta=13.67 min | t_ocup=1161.93 min
#   m2: consultas=87 | ocup=99.14% | tm_consulta=13.30 min | t_ocup=1157.52 min
# Doentes atendidos: 241
# Tempo médio de espera (min): 283.79
# Tempo médio de consulta (min): 14.51
# Tempo médio no sistema (min): 298.31
# Tamanho médio da fila: 56.29 | Máx: 126
# Ocupação média: 0.993
# Ocupação por médico (%):
#   m0: 98.72%
#   m1: 99.84%
#   m2: 98.18%
# Métricas por médico:
#   m0: consultas=79 | ocup=98.72% | tm_consulta=14.73 min | t_ocup=1163.67 min
#   m1: consultas=90 | ocup=99.84% | tm_consulta=13.08 min | t_ocup=1176.87 min
#   m2: consultas=72 | ocup=98.18% | tm_consulta=16.07 min | t_ocup=1157.24 min
# Doentes atendidos: 234
# Tempo médio de espera (min): 348.82
# Tempo médio de consulta (min): 15.55
# Tempo médio no sistema (min): 364.37
# Tamanho médio da fila: 63.81 | Máx: 138
# Ocupação média: 0.994
# Ocupação por médico (%):
#   m0: 99.55%
#   m1: 99.31%
#   m2: 98.15%
# Métricas por médico:
#   m0: consultas=78 | ocup=99.55% | tm_consulta=15.63 min | t_ocup=1219.33 min
#   m1: consultas=73 | ocup=99.31% | tm_consulta=16.66 min | t_ocup=1216.37 min
#   m2: consultas=83 | ocup=98.15% | tm_consulta=14.48 min | t_ocup=1202.15 min
# Doentes atendidos: 227
# Tempo médio de espera (min): 356.25
# Tempo médio de consulta (min): 15.8
# Tempo médio no sistema (min): 372.05
# Tamanho médio da fila: 66.89 | Máx: 139
# Ocupação média: 0.993
# Ocupação por médico (%):
#   m0: 99.69%
#   m1: 98.09%
#   m2: 99.59%
# Métricas por médico:
#   m0: consultas=63 | ocup=99.69% | tm_consulta=19.08 min | t_ocup=1202.15 min
#   m1: consultas=73 | ocup=98.09% | tm_consulta=16.20 min | t_ocup=1182.80 min
#   m2: consultas=91 | ocup=99.59% | tm_consulta=13.20 min | t_ocup=1200.92 min
# Doentes atendidos: 238
# Tempo médio de espera (min): 450.59
# Tempo médio de consulta (min): 16.67
# Tempo médio no sistema (min): 467.25
# Tamanho médio da fila: 79.14 | Máx: 162
# Ocupação média: 0.989
# Ocupação por médico (%):
#   m0: 96.4%
#   m1: 99.42%
#   m2: 95.97%
# Métricas por médico:
#   m0: consultas=78 | ocup=96.40% | tm_consulta=16.80 min | t_ocup=1310.45 min
#   m1: consultas=83 | ocup=99.42% | tm_consulta=16.28 min | t_ocup=1351.56 min
#   m2: consultas=77 | ocup=95.97% | tm_consulta=16.94 min | t_ocup=1304.60 min
# Doentes atendidos: 235
# Tempo médio de espera (min): 333.48
# Tempo médio de consulta (min): 15.17
# Tempo médio no sistema (min): 348.64
# Tamanho médio da fila: 67.25 | Máx: 130
# Ocupação média: 0.991
# Ocupação por médico (%):
#   m0: 96.73%
#   m1: 98.42%
#   m2: 98.75%
# Métricas por médico:
#   m0: consultas=68 | ocup=96.73% | tm_consulta=17.25 min | t_ocup=1173.00 min
#   m1: consultas=81 | ocup=98.42% | tm_consulta=14.73 min | t_ocup=1193.50 min
#   m2: consultas=86 | ocup=98.75% | tm_consulta=13.92 min | t_ocup=1197.51 min
# Doentes atendidos: 224
# Tempo médio de espera (min): 309.59
# Tempo médio de consulta (min): 15.96
# Tempo médio no sistema (min): 325.54
# Tamanho médio da fila: 61.64 | Máx: 124
# Ocupação média: 0.993
# Ocupação por médico (%):
#   m0: 94.88%
#   m1: 99.91%
#   m2: 97.06%
# Métricas por médico:
#   m0: consultas=73 | ocup=94.88% | tm_consulta=15.92 min | t_ocup=1161.93 min
#   m1: consultas=75 | ocup=99.91% | tm_consulta=16.31 min | t_ocup=1223.57 min
#   m2: consultas=76 | ocup=97.06% | tm_consulta=15.64 min | t_ocup=1188.64 min
# Doentes atendidos: 232
# Tempo médio de espera (min): 329.5
# Tempo médio de consulta (min): 14.97
# Tempo médio no sistema (min): 344.48
# Tamanho médio da fila: 68.3 | Máx: 130
# Ocupação média: 0.987
# Ocupação por médico (%):
#   m0: 97.55%
#   m1: 98.88%
#   m2: 96.06%
# Métricas por médico:
#   m0: consultas=70 | ocup=97.55% | tm_consulta=16.55 min | t_ocup=1158.47 min
#   m1: consultas=89 | ocup=98.88% | tm_consulta=13.19 min | t_ocup=1174.31 min
#   m2: consultas=73 | ocup=96.06% | tm_consulta=15.63 min | t_ocup=1140.76 min
# Doentes atendidos: 219
# Tempo médio de espera (min): 339.11
# Tempo médio de consulta (min): 16.16
# Tempo médio no sistema (min): 355.27
# Tamanho médio da fila: 57.73 | Máx: 131
# Ocupação média: 0.989
# Ocupação por médico (%):
#   m0: 99.52%
#   m1: 97.69%
#   m2: 98.33%
# Métricas por médico:
#   m0: consultas=71 | ocup=99.52% | tm_consulta=16.79 min | t_ocup=1191.78 min
#   m1: consultas=64 | ocup=97.69% | tm_consulta=18.28 min | t_ocup=1169.86 min
#   m2: consultas=84 | ocup=98.33% | tm_consulta=14.02 min | t_ocup=1177.56 min
# Doentes atendidos: 234
# Tempo médio de espera (min): 400.25
# Tempo médio de consulta (min): 16.37
# Tempo médio no sistema (min): 416.63
# Tamanho médio da fila: 77.1 | Máx: 139
# Ocupação média: 0.99
# Ocupação por médico (%):
#   m0: 99.46%
#   m1: 98.45%
#   m2: 97.15%
# Métricas por médico:
#   m0: consultas=74 | ocup=99.46% | tm_consulta=17.45 min | t_ocup=1291.32 min
#   m1: consultas=73 | ocup=98.45% | tm_consulta=17.51 min | t_ocup=1278.20 min
#   m2: consultas=87 | ocup=97.15% | tm_consulta=14.50 min | t_ocup=1261.23 min
# Doentes atendidos: 238
# Tempo médio de espera (min): 271.75
# Tempo médio de consulta (min): 13.27
# Tempo médio no sistema (min): 285.02
# Tamanho médio da fila: 62.95 | Máx: 126
# Ocupação média: 0.992
# Ocupação por médico (%):
#   m0: 99.81%
#   m1: 95.65%
#   m2: 95.87%
# Métricas por médico:
#   m0: consultas=70 | ocup=99.81% | tm_consulta=15.46 min | t_ocup=1082.41 min
#   m1: consultas=87 | ocup=95.65% | tm_consulta=11.92 min | t_ocup=1037.32 min
#   m2: consultas=81 | ocup=95.87% | tm_consulta=12.84 min | t_ocup=1039.68 min
# Doentes atendidos: 216
# Tempo médio de espera (min): 279.01
# Tempo médio de consulta (min): 14.72
# Tempo médio no sistema (min): 293.72
# Tamanho médio da fila: 57.06 | Máx: 121
# Ocupação média: 0.991
# Ocupação por médico (%):
#   m0: 98.26%
#   m1: 99.25%
#   m2: 98.12%
# Métricas por médico:
#   m0: consultas=62 | ocup=98.26% | tm_consulta=17.04 min | t_ocup=1056.61 min
#   m1: consultas=75 | ocup=99.25% | tm_consulta=14.23 min | t_ocup=1067.22 min
#   m2: consultas=79 | ocup=98.12% | tm_consulta=13.36 min | t_ocup=1055.08 min
# Doentes atendidos: 234
# Tempo médio de espera (min): 327.21
# Tempo médio de consulta (min): 14.42
# Tempo médio no sistema (min): 341.63
# Tamanho médio da fila: 68.98 | Máx: 128
# Ocupação média: 0.994
# Ocupação por médico (%):
#   m0: 95.96%
#   m1: 99.94%
#   m2: 96.16%
# Métricas por médico:
#   m0: consultas=81 | ocup=95.96% | tm_consulta=13.69 min | t_ocup=1108.54 min
#   m1: consultas=84 | ocup=99.94% | tm_consulta=13.74 min | t_ocup=1154.50 min
#   m2: consultas=69 | ocup=96.16% | tm_consulta=16.10 min | t_ocup=1110.82 min
# Doentes atendidos: 224
# Tempo médio de espera (min): 293.8
# Tempo médio de consulta (min): 14.95
# Tempo médio no sistema (min): 308.76
# Tamanho médio da fila: 63.13 | Máx: 128
# Ocupação média: 0.993
# Ocupação por médico (%):
#   m0: 98.23%
#   m1: 99.5%
#   m2: 96.25%
# Métricas por médico:
#   m0: consultas=80 | ocup=98.23% | tm_consulta=13.99 min | t_ocup=1119.24 min
#   m1: consultas=64 | ocup=99.50% | tm_consulta=17.71 min | t_ocup=1133.76 min
#   m2: consultas=80 | ocup=96.25% | tm_consulta=13.71 min | t_ocup=1096.71 min
# Doentes atendidos: 227
# Tempo médio de espera (min): 302.95
# Tempo médio de consulta (min): 15.62
# Tempo médio no sistema (min): 318.58
# Tamanho médio da fila: 59.89 | Máx: 121
# Ocupação média: 0.99
# Ocupação por médico (%):
#   m0: 98.61%
#   m1: 99.6%
#   m2: 99.67%
# Métricas por médico:
#   m0: consultas=73 | ocup=98.61% | tm_consulta=16.08 min | t_ocup=1174.07 min
#   m1: consultas=85 | ocup=99.60% | tm_consulta=13.95 min | t_ocup=1185.85 min
#   m2: consultas=69 | ocup=99.67% | tm_consulta=17.20 min | t_ocup=1186.71 min
# Doentes atendidos: 249
# Tempo médio de espera (min): 421.79
# Tempo médio de consulta (min): 15.77
# Tempo médio no sistema (min): 437.56
# Tamanho médio da fila: 80.63 | Máx: 169
# Ocupação média: 0.994
# Ocupação por médico (%):
#   m0: 98.55%
#   m1: 99.71%
#   m2: 98.1%
# Métricas por médico:
#   m0: consultas=73 | ocup=98.55% | tm_consulta=17.89 min | t_ocup=1306.06 min
#   m1: consultas=101 | ocup=99.71% | tm_consulta=13.08 min | t_ocup=1321.36 min
#   m2: consultas=75 | ocup=98.10% | tm_consulta=17.33 min | t_ocup=1300.06 min
# Doentes atendidos: 236
# Tempo médio de espera (min): 308.72
# Tempo médio de consulta (min): 14.57
# Tempo médio no sistema (min): 323.28
# Tamanho médio da fila: 66.75 | Máx: 130
# Ocupação média: 0.994
# Ocupação por médico (%):
#   m0: 97.07%
#   m1: 99.41%
#   m2: 95.4%
# Métricas por médico:
#   m0: consultas=89 | ocup=97.07% | tm_consulta=12.85 min | t_ocup=1143.26 min
#   m1: consultas=69 | ocup=99.41% | tm_consulta=16.97 min | t_ocup=1170.75 min
#   m2: consultas=78 | ocup=95.40% | tm_consulta=14.40 min | t_ocup=1123.54 min
# Doentes atendidos: 224
# Tempo médio de espera (min): 319.6
# Tempo médio de consulta (min): 14.82
# Tempo médio no sistema (min): 334.43
# Tamanho médio da fila: 65.17 | Máx: 125
# Ocupação média: 0.993
# Ocupação por médico (%):
#   m0: 98.31%
#   m1: 99.34%
#   m2: 97.51%
# Métricas por médico:
#   m0: consultas=60 | ocup=98.31% | tm_consulta=18.43 min | t_ocup=1105.88 min
#   m1: consultas=91 | ocup=99.34% | tm_consulta=12.28 min | t_ocup=1117.53 min
#   m2: consultas=73 | ocup=97.51% | tm_consulta=15.03 min | t_ocup=1096.96 min
# Doentes atendidos: 240
# Tempo médio de espera (min): 354.74
# Tempo médio de consulta (min): 14.95
# Tempo médio no sistema (min): 369.69
# Tamanho médio da fila: 67.26 | Máx: 142
# Ocupação média: 0.994
# Ocupação por médico (%):
#   m0: 99.42%
#   m1: 99.2%
#   m2: 99.07%
# Métricas por médico:
#   m0: consultas=66 | ocup=99.42% | tm_consulta=18.16 min | t_ocup=1198.36 min
#   m1: consultas=84 | ocup=99.20% | tm_consulta=14.24 min | t_ocup=1195.77 min
#   m2: consultas=90 | ocup=99.07% | tm_consulta=13.27 min | t_ocup=1194.15 min
# Doentes atendidos: 235
# Tempo médio de espera (min): 341.62
# Tempo médio de consulta (min): 15.99
# Tempo médio no sistema (min): 357.61
# Tamanho médio da fila: 62.21 | Máx: 122
# Ocupação média: 0.994
# Ocupação por médico (%):
#   m0: 97.44%
#   m1: 99.76%
#   m2: 98.47%
# Métricas por médico:
#   m0: consultas=88 | ocup=97.44% | tm_consulta=14.08 min | t_ocup=1238.69 min
#   m1: consultas=66 | ocup=99.76% | tm_consulta=19.22 min | t_ocup=1268.23 min
#   m2: consultas=81 | ocup=98.47% | tm_consulta=15.45 min | t_ocup=1251.81 min
# Doentes atendidos: 228
# Tempo médio de espera (min): 386.47
# Tempo médio de consulta (min): 15.63
# Tempo médio no sistema (min): 402.1
# Tamanho médio da fila: 73.03 | Máx: 141
# Ocupação média: 0.991
# Ocupação por médico (%):
#   m0: 99.33%
#   m1: 98.41%
#   m2: 97.82%
# Métricas por médico:
#   m0: consultas=83 | ocup=99.33% | tm_consulta=14.43 min | t_ocup=1197.36 min
#   m1: consultas=68 | ocup=98.41% | tm_consulta=17.44 min | t_ocup=1186.26 min
#   m2: consultas=77 | ocup=97.82% | tm_consulta=15.31 min | t_ocup=1179.21 min
# Doentes atendidos: 251
# Tempo médio de espera (min): 375.61
# Tempo médio de consulta (min): 14.75
# Tempo médio no sistema (min): 390.37
# Tamanho médio da fila: 70.33 | Máx: 152
# Ocupação média: 0.99
# Ocupação por médico (%):
#   m0: 99.12%
#   m1: 96.67%
#   m2: 96.9%
# Métricas por médico:
#   m0: consultas=89 | ocup=99.12% | tm_consulta=14.09 min | t_ocup=1253.92 min
#   m1: consultas=76 | ocup=96.67% | tm_consulta=16.09 min | t_ocup=1222.92 min
#   m2: consultas=86 | ocup=96.90% | tm_consulta=14.25 min | t_ocup=1225.88 min
# Doentes atendidos: 259
# Tempo médio de espera (min): 361.32
# Tempo médio de consulta (min): 13.61
# Tempo médio no sistema (min): 374.92
# Tamanho médio da fila: 80.32 | Máx: 160
# Ocupação média: 0.992
# Ocupação por médico (%):
#   m0: 98.58%
#   m1: 99.12%
#   m2: 98.8%
# Métricas por médico:
#   m0: consultas=80 | ocup=98.58% | tm_consulta=14.65 min | t_ocup=1171.66 min
#   m1: consultas=92 | ocup=99.12% | tm_consulta=12.81 min | t_ocup=1178.08 min
#   m2: consultas=87 | ocup=98.80% | tm_consulta=13.50 min | t_ocup=1174.29 min
# Doentes atendidos: 271
# Tempo médio de espera (min): 387.18
# Tempo médio de consulta (min): 13.96
# Tempo médio no sistema (min): 401.15
# Tamanho médio da fila: 89.01 | Máx: 165
# Ocupação média: 0.994
# Ocupação por médico (%):
#   m0: 97.28%
#   m1: 98.64%
#   m2: 99.84%
# Métricas por médico:
#   m0: consultas=96 | ocup=97.28% | tm_consulta=12.97 min | t_ocup=1244.67 min
#   m1: consultas=90 | ocup=98.64% | tm_consulta=14.02 min | t_ocup=1261.99 min
#   m2: consultas=85 | ocup=99.84% | tm_consulta=15.03 min | t_ocup=1277.31 min
# Doentes atendidos: 237
# Tempo médio de espera (min): 358.75
# Tempo médio de consulta (min): 15.38
# Tempo médio no sistema (min): 374.13
# Tamanho médio da fila: 71.95 | Máx: 145
# Ocupação média: 0.994
# Ocupação por médico (%):
#   m0: 99.76%
#   m1: 99.95%
#   m2: 99.82%
# Métricas por médico:
#   m0: consultas=76 | ocup=99.76% | tm_consulta=15.98 min | t_ocup=1214.10 min
#   m1: consultas=79 | ocup=99.95% | tm_consulta=15.40 min | t_ocup=1216.41 min
#   m2: consultas=82 | ocup=99.82% | tm_consulta=14.82 min | t_ocup=1214.90 min
# Doentes atendidos: 234
# Tempo médio de espera (min): 317.76
# Tempo médio de consulta (min): 14.08
# Tempo médio no sistema (min): 331.84
# Tamanho médio da fila: 66.12 | Máx: 136
# Ocupação média: 0.991
# Ocupação por médico (%):
#   m0: 99.78%
#   m1: 99.65%
#   m2: 99.71%
# Métricas por médico:
#   m0: consultas=78 | ocup=99.78% | tm_consulta=14.09 min | t_ocup=1099.28 min
#   m1: consultas=85 | ocup=99.65% | tm_consulta=12.92 min | t_ocup=1097.79 min
#   m2: consultas=71 | ocup=99.71% | tm_consulta=15.47 min | t_ocup=1098.48 min
# Doentes atendidos: 241
# Tempo médio de espera (min): 338.12
# Tempo médio de consulta (min): 14.12
# Tempo médio no sistema (min): 352.24
# Tamanho médio da fila: 71.15 | Máx: 143
# Ocupação média: 0.989
# Ocupação por médico (%):
#   m0: 99.74%
#   m1: 97.28%
#   m2: 97.8%
# Métricas por médico:
#   m0: consultas=75 | ocup=99.74% | tm_consulta=15.35 min | t_ocup=1151.40 min
#   m1: consultas=76 | ocup=97.28% | tm_consulta=14.78 min | t_ocup=1122.97 min
#   m2: consultas=90 | ocup=97.80% | tm_consulta=12.54 min | t_ocup=1128.93 min
# Doentes atendidos: 240
# Tempo médio de espera (min): 406.81
# Tempo médio de consulta (min): 16.31
# Tempo médio no sistema (min): 423.12
# Tamanho médio da fila: 75.07 | Máx: 155
# Ocupação média: 0.994
# Ocupação por médico (%):
#   m0: 99.19%
#   m1: 99.97%
#   m2: 99.11%
# Métricas por médico:
#   m0: consultas=90 | ocup=99.19% | tm_consulta=14.46 min | t_ocup=1301.53 min
#   m1: consultas=73 | ocup=99.97% | tm_consulta=17.97 min | t_ocup=1311.72 min
#   m2: consultas=77 | ocup=99.11% | tm_consulta=16.89 min | t_ocup=1300.47 min
# Doentes atendidos: 265
# Tempo médio de espera (min): 397.67
# Tempo médio de consulta (min): 14.68
# Tempo médio no sistema (min): 412.35
# Tamanho médio da fila: 80.42 | Máx: 167
# Ocupação média: 0.994
# Ocupação por médico (%):
#   m0: 97.59%
#   m1: 99.6%
#   m2: 97.06%
# Métricas por médico:
#   m0: consultas=98 | ocup=97.59% | tm_consulta=13.16 min | t_ocup=1289.84 min
#   m1: consultas=87 | ocup=99.60% | tm_consulta=15.13 min | t_ocup=1316.32 min
#   m2: consultas=80 | ocup=97.06% | tm_consulta=16.04 min | t_ocup=1282.85 min
